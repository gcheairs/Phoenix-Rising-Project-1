# %%
# Import Dependencies
import pandas as pd

# %%
# Read file into DataFrame
medi_df = pd.read_csv('Resources/Medicare_Part_D_Spending_by_Drug_2021.csv')
#medi_df.head(20)
medi_df
# Out:
#                            Brnd_Name                 Gnrc_Name  Tot_Mftr  \
# 0           1st Tier Unifine Pentips      Pen Needle, Diabetic         1
# 1           1st Tier Unifine Pentips      Pen Needle, Diabetic         1
# 2      1st Tier Unifine Pentips Plus      Pen Needle, Diabetic         1
# 3      1st Tier Unifine Pentips Plus      Pen Needle, Diabetic         1
# 4                           Abacavir          Abacavir Sulfate         7
# ...                              ...                       ...       ...
# 13746                          Zyvox                 Linezolid         1
# 13747                          Zyvox                 Linezolid         1
# 13748                          Zyvox  Linezolid In Dextrose 5%         2
# 13749                          Zyvox  Linezolid In Dextrose 5%         1
# 13750                          Zyvox  Linezolid In Dextrose 5%         1
#
#              Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0              Overall        217938.04          1014318.0         8595.0
# 1      Owen Mumford Us        217938.04          1014318.0         8595.0
# 2              Overall        402124.68          1850703.0        15403.0
# 3      Owen Mumford Us        402124.68          1850703.0        15403.0
# 4              Overall      13386250.08          3189707.0        48283.0
# ...                ...              ...                ...            ...
# 13746          Overall       1479764.75            15702.0          393.0
# 13747  Pharmaci/Pfizer       1479764.75            15702.0          393.0
# 13748          Overall        307653.43          1158228.0          401.0
# 13749  Pharmaci/Pfizer        232528.98           867822.0          313.0
# 13750  Phar-Prep/Pfize         75124.45           290406.0           88.0
#
#        Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 0              3025.0                         0.216105              25.356375
# 1              3025.0                         0.216105              25.356375
# 2              5967.0                         0.217359              26.106906
# 3              5967.0                         0.217359              26.106906
# 4              8090.0                         4.298589             277.245616
# ...               ...                              ...                    ...
# 13746           330.0                       161.816476            3765.304707
# 13747           330.0                       161.816476            3765.304707
# 13748           164.0                         0.271663             767.215536
# 13749           126.0                         0.275311             742.904089
# 13750            44.0                         0.258688             853.686932
#
#        ...  Tot_Spndng_2021  Tot_Dsg_Unts_2021  Tot_Clms_2021  Tot_Benes_2021  \
# 0      ...        102280.76           459384.0           3708          1313.0
# 1      ...        102280.76           459384.0           3708          1313.0
# 2      ...        131927.33           566872.0           4564          1766.0
# 3      ...        131927.33           566872.0           4564          1766.0
# 4      ...       7038593.83          2501447.0          30540          4254.0
# ...    ...              ...                ...            ...             ...
# 13746  ...         69590.61             1255.0             43            34.0
# 13747  ...         69590.61             1255.0             43            34.0
# 13748  ...         48776.09           298817.0            159            56.0
# 13749  ...         39241.77           239417.0            122            48.0
# 13750  ...          9534.32            59400.0             37             NaN
#
#        Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# 0                             0.223001              27.583808
# 1                             0.223001              27.583808
# 2                             0.232812              28.906076
# 3                             0.232812              28.906076
# 4                             3.187698             230.471311
# ...                                ...                    ...
# 13746                        55.450685            1618.386279
# 13747                        55.450685            1618.386279
# 13748                         0.163115             306.767862
# 13749                         0.163906             321.653852
# 13750                         0.160510             257.684324
#
#        Avg_Spnd_Per_Bene_2021  Outlier_Flag_2021  \
# 0                   77.898522                  0
# 1                   77.898522                  0
# 2                   74.704037                  0
# 3                   74.704037                  0
# 4                 1654.582471                  0
# ...                       ...                ...
# 13746             2046.782647                  1
# 13747             2046.782647                  1
# 13748              871.001607                  0
# 13749              817.536875                  0
# 13750                     NaN                  0
#
#        Chg_Avg_Spnd_Per_Dsg_Unt_20_21  CAGR_Avg_Spnd_Per_Dsg_Unt_17_21
# 0                            0.024346                         0.007885
# 1                            0.024346                         0.007885
# 2                            0.159124                         0.017317
# 3                            0.159124                         0.017317
# 4                           -0.087066                        -0.072022
# ...                               ...                              ...
# 13746                       -0.650784                        -0.234895
# 13747                       -0.650784                        -0.234895
# 13748                       -0.004769                        -0.119729
# 13749                        0.001126                        -0.121599
# 13750                       -0.022745                        -0.112472
#
# [13751 rows x 46 columns]

# %%
medi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13751 entries, 0 to 13750
# Data columns (total 46 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Brnd_Name                        13751 non-null  object
#  1   Gnrc_Name                        13751 non-null  object
#  2   Tot_Mftr                         13751 non-null  int64
#  3   Mftr_Name                        13751 non-null  object
#  4   Tot_Spndng_2017                  9357 non-null   float64
#  5   Tot_Dsg_Unts_2017                9357 non-null   float64
#  6   Tot_Clms_2017                    9357 non-null   float64
#  7   Tot_Benes_2017                   9289 non-null   float64
#  8   Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  9357 non-null   float64
#  9   Avg_Spnd_Per_Clm_2017            9357 non-null   float64
#  10  Avg_Spnd_Per_Bene_2017           9175 non-null   float64
#  11  Outlier_Flag_2017                9357 non-null   float64
#  12  Tot_Spndng_2018                  10371 non-null  float64
#  13  Tot_Dsg_Unts_2018                10371 non-null  float64
#  14  Tot_Clms_2018                    10371 non-null  float64
#  15  Tot_Benes_2018                   10217 non-null  float64
#  16  Avg_Spnd_Per_Dsg_Unt_Wghtd_2018  10371 non-null  float64
#  17  Avg_Spnd_Per_Clm_2018            10371 non-null  float64
#  18  Avg_Spnd_Per_Bene_2018           10164 non-null  float64
#  19  Outlier_Flag_2018                10371 non-null  float64
#  20  Tot_Spndng_2019                  11481 non-null  float64
#  21  Tot_Dsg_Unts_2019                11481 non-null  float64
#  22  Tot_Clms_2019                    11481 non-null  float64
#  23  Tot_Benes_2019                   11227 non-null  float64
#  24  Avg_Spnd_Per_Dsg_Unt_Wghtd_2019  11481 non-null  float64
#  25  Avg_Spnd_Per_Clm_2019            11481 non-null  float64
#  26  Avg_Spnd_Per_Bene_2019           11211 non-null  float64
#  27  Outlier_Flag_2019                11481 non-null  float64
#  28  Tot_Spndng_2020                  12561 non-null  float64
#  29  Tot_Dsg_Unts_2020                12561 non-null  float64
#  30  Tot_Clms_2020                    12561 non-null  float64
#  31  Tot_Benes_2020                   12185 non-null  float64
#  32  Avg_Spnd_Per_Dsg_Unt_Wghtd_2020  12561 non-null  float64
#  33  Avg_Spnd_Per_Clm_2020            12561 non-null  float64
#  34  Avg_Spnd_Per_Bene_2020           12182 non-null  float64
#  35  Outlier_Flag_2020                12561 non-null  float64
#  36  Tot_Spndng_2021                  13751 non-null  float64
#  37  Tot_Dsg_Unts_2021                13751 non-null  float64
#  38  Tot_Clms_2021                    13751 non-null  int64
#  39  Tot_Benes_2021                   13003 non-null  float64
#  40  Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  13751 non-null  float64
#  41  Avg_Spnd_Per_Clm_2021            13751 non-null  float64
#  42  Avg_Spnd_Per_Bene_2021           13003 non-null  float64
#  43  Outlier_Flag_2021                13751 non-null  int64
#  44  Chg_Avg_Spnd_Per_Dsg_Unt_20_21   12561 non-null  float64
#  45  CAGR_Avg_Spnd_Per_Dsg_Unt_17_21  12665 non-null  float64
# dtypes: float64(40), int64(3), object(3)
# memory usage: 4.8+ MB

# %%
#Set an index

medi_index = medi_df.set_index('Gnrc_Name')
medi_index
#Filter for insulin drug (we need only insulin)
medi_filtered_df = medi_index.loc[['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']]

medi_filtered_df
# Out:
#                                             Brnd_Name  Tot_Mftr  \
# Gnrc_Name
# Insulin Glulisine                              Apidra         1
# Insulin Glulisine                              Apidra         1
# Insulin Glulisine                     Apidra Solostar         1
# Insulin Glulisine                     Apidra Solostar         1
# Insulin Lispro                                Admelog         1
# Insulin Lispro                                Admelog         1
# Insulin Lispro                       Admelog Solostar         1
# Insulin Lispro                       Admelog Solostar         1
# Insulin Lispro                                Humalog         1
# Insulin Lispro                                Humalog         1
# Insulin Lispro                 Humalog Junior Kwikpen         1
# Insulin Lispro                 Humalog Junior Kwikpen         1
# Insulin Lispro                  Humalog Kwikpen U-100         1
# Insulin Lispro                  Humalog Kwikpen U-100         1
# Insulin Lispro                  Humalog Kwikpen U-200         1
# Insulin Lispro                  Humalog Kwikpen U-200         1
# Insulin Lispro                         Insulin Lispro         1
# Insulin Lispro                         Insulin Lispro         1
# Insulin Lispro          Insulin Lispro Junior Kwikpen         1
# Insulin Lispro          Insulin Lispro Junior Kwikpen         1
# Insulin Lispro           Insulin Lispro Kwikpen U-100         1
# Insulin Lispro           Insulin Lispro Kwikpen U-100         1
# Insulin Aspart                         Insulin Aspart         1
# Insulin Aspart                         Insulin Aspart         1
# Insulin Aspart                 Insulin Aspart Flexpen         1
# Insulin Aspart                 Insulin Aspart Flexpen         1
# Insulin Aspart                 Insulin Aspart Penfill         1
# Insulin Aspart                 Insulin Aspart Penfill         1
# Insulin Aspart                                Novolog         2
# Insulin Aspart                                Novolog         1
# Insulin Aspart                                Novolog         1
# Insulin Aspart                        Novolog Flexpen         2
# Insulin Aspart                        Novolog Flexpen         1
# Insulin Aspart                        Novolog Flexpen         1
# Insulin Aspart                        Novolog Penfill         1
# Insulin Aspart                        Novolog Penfill         1
# Insulin Regular, Human                        Afrezza         1
# Insulin Regular, Human                        Afrezza         1
# Insulin Regular, Human                      Humulin R         1
# Insulin Regular, Human                      Humulin R         1
# Insulin Regular, Human                Humulin R U-500         1
# Insulin Regular, Human                Humulin R U-500         1
# Insulin Regular, Human        Humulin R U-500 Kwikpen         1
# Insulin Regular, Human          Overall              NaN                NaN
# Insulin Regular, Human  Novo Nordisk-Wa              NaN                NaN
# Insulin Regular, Human     Novo Nordisk              NaN                NaN
#
#                         Tot_Clms_2017  Tot_Benes_2017  \
# Gnrc_Name
# Insulin Glulisine             12635.0          3470.0
# Insulin Glulisine             12635.0          3470.0
# Insulin Glulisine             25100.0          7710.0
# Insulin Glulisine             25100.0          7710.0
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro              1217401.0        282797.0
# Insulin Lispro              1217401.0        282797.0
# Insulin Lispro                  119.0           110.0
# Insulin Lispro                  119.0           110.0
# Insulin Lispro              1512965.0        414218.0
# Insulin Lispro              1512965.0        414218.0
# Insulin Lispro                83023.0         23564.0
# Insulin Lispro                83023.0         23564.0
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart              1271339.0        282388.0
# Insulin Aspart                    NaN             NaN
# Insulin Aspart              1271339.0        282388.0
# Insulin Aspart              2185868.0        545984.0
# Insulin Aspart                    NaN             NaN
# Insulin Aspart              2185868.0        545984.0
# Insulin Aspart                 8004.0          3153.0
# Insulin Aspart                 8004.0          3153.0
# Insulin Regular, Human         2609.0           745.0
# Insulin Regular, Human         2609.0           739.0
# Insulin Regular, Human       366577.0        101959.0
# Insulin Regular, Human       366577.0        101959.0
# Insulin Regular, Human        73118.0         14518.0
# Insulin Regular, Human        73118.0         14518.0
# Insulin Regular, Human        66294.0         13128.0
# Insulin Regular, Human        66294.0         13128.0
# Insulin Regular, Human       363075.0         90606.0
# Insulin Regular, Human        75781.0         21536.0
# Insulin Regular, Human       287294.0         71505.0
# Insulin Regular, Human            NaN             NaN
# Insulin Regular, Human            NaN             NaN
# Insulin Regular, Human            NaN             NaN
#
#                         Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  \
# Gnrc_Name
# Insulin Glulisine                             25.022690
# Insulin Glulisine                             25.022690
# Insulin Glulisine                             32.156073
# Insulin Glulisine                             32.156073
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                25.728293
# Insulin Lispro                                25.728293
# Insulin Lispro                                34.191917
# Insulin Lispro                                34.191917
# Insulin Lispro                                33.537697
# Insulin Lispro                                33.537697
# Insulin Lispro                                67.970772
# Insulin Lispro                                67.970772
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                27.640665
# Insulin Aspart                                      NaN
# Insulin Aspart                                27.640665
# Insulin Aspart                                35.228346
# Insulin Aspart                                      NaN
# Insulin Aspart                                35.228346
# Insulin Aspart                                33.581589
# Insulin Aspart                                33.581589
# Insulin Regular, Human                         3.835182
# Insulin Regular, Human                         3.835182
# Insulin Regular, Human                         9.737912
# Insulin Regular, Human                         9.737912
# Insulin Regular, Human                        70.642568
# Insulin Regular, Human                        70.642568
# Insulin Regular, Human                        91.136349
# Insulin Regular, Human                        91.136349
# Insulin Regular, Human                        11.769963
# Insulin Regular, Human                         2.847518
# Insulin Regular, Human                        14.123481
# Insulin Regular, Human                              NaN
# Insulin Regular, Human                              NaN
# Insulin Regular, Human                              NaN
#
#                         Avg_Spnd_Per_Clm_2017  Avg_Spnd_Per_Bene_2017  ...  \
# Gnrc_Name                                                              ...
# Insulin Glulisine                  713.280344             2597.203790  ...
# Insulin Glulisine                  713.280344             2597.203790  ...
# Insulin Glulisine                  758.771875             2470.191188  ...
# Insulin Glulisine                  758.771875             2470.191188  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro
# Insulin Aspart                                      NaN
# Insulin Aspart                                 0.021895
# Insulin Aspart                                 0.022360
# Insulin Aspart                                 0.022360
# Insulin Regular, Human                         0.218834
# Insulin Regular, Human                         0.218834
# Insulin Regular, Human                        -0.001431
# Insulin Regular, Human                        -0.001431
# Insulin Regular, Human                         0.017117
# Insulin Regular, Human                         0.017117
# Insulin Regular, Human                         0.012391
# Insulin Regular, Human                         0.012391
# Insulin Regular, Human                         0.008109
# Insulin Regular, Human                         0.003131
# Insulin Regular, Human                         0.002185
# Insulin Regular, Human                         0.148267
# Insulin Regular, Human                         0.021860
# Insulin Regular, Human                         0.008056
#
# [50 rows x 45 columns]

# %%
#change the spending columns to more user friendly numbers for plotting  
# Define a formatting function to format float values to two decimal places
def format_float(value):
    return '{:.2f}'.format(value)

# Specify the columns to format
columns_to_format = ['Tot_Spndng_2019', 'Tot_Dsg_Unts_2019', 'Tot_Spndng_2020', 'Tot_Dsg_Unts_2020', 'Tot_Spndng_2021', 'Tot_Dsg_Unts_2021']

# Apply the formatting function to the selected columns
medi_filtered_df[columns_to_format] = medi_filtered_df[columns_to_format].applymap(format_float)

medi_filtered_df
# Out:
# C:\Users\cfgoi\AppData\Local\Temp\ipykernel_23208\2510458509.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   medi_filtered_df[columns_to_format] = medi_filtered_df[columns_to_format].applymap(format_float)
#                                             Brnd_Name  Tot_Mftr  \
# Gnrc_Name
# Insulin Glulisine                              Apidra         1
# Insulin Glulisine                              Apidra         1
# Insulin Glulisine                     Apidra Solostar         1
# Insulin Glulisine                     Apidra Solostar         1
# Insulin Lispro                                Admelog         1
# Insulin Lispro                                Admelog         1
# Insulin Lispro                       Admelog Solostar         1
# Insulin Lispro                       Admelog Solostar         1
# Insulin Lispro                                Humalog         1
# Insulin Lispro                                Humalog         1
# Insulin Lispro                 Humalog Junior Kwikpen         1
# Insulin Lispro                 Humalog Junior Kwikpen         1
# Insulin Lispro                  Humalog Kwikpen U-100         1
# Insulin Lispro                  Humalog Kwikpen U-100         1
# Insulin Lispro                  Humalog Kwikpen U-200         1
# Insulin Lispro                  Humalog Kwikpen U-200         1
# Insulin Lispro                         Insulin Lispro         1
# Insulin Lispro                         Insulin Lispro         1
# Insulin Lispro          Insulin Lispro Junior Kwikpen         1
# Insulin Lispro          Insulin Lispro Junior Kwikpen         1
# Insulin Lispro           Insulin Lispro Kwikpen U-100         1
# Insulin Lispro           Insulin Lispro Kwikpen U-100         1
# Insulin Aspart                         Insulin Aspart         1
# Insulin Aspart                         Insulin Aspart         1
# Insulin Aspart                 Insulin Aspart Flexpen         1
# Insulin Aspart                 Insulin Aspart Flexpen         1
# Insulin Aspart                 Insulin Aspart Penfill         1
# Insulin Aspart                 Insulin Aspart Penfill         1
# Insulin Aspart                                Novolog         2
# Insulin Aspart                                Novolog         1
# Insulin Aspart                                Novolog         1
# Insulin Aspart                        Novolog Flexpen         2
# Insulin Aspart                        Novolog Flexpen         1
# Insulin Aspart                        Novolog Flexpen         1
# Insulin Aspart                        Novolog Penfill         1
# Insulin Aspart                        Novolog Penfill         1
# Insulin Regular, Human  Eli Lilly & Co.     1.455244e+08       2.060010e+06
# Insulin Regular, Human          Overall     1.016533e+08       1.115398e+06
# Insulin Regular, Human  Eli Lilly & Co.     1.016533e+08       1.115398e+06
# Insulin Regular, Human          Overall     6.831130e+07       6.395996e+06
# Insulin Regular, Human  Novo Nordisk-Wa     5.561320e+06       1.953041e+06
# Insulin Regular, Human     Novo Nordisk     6.274998e+07       4.442954e+06
# Insulin Regular, Human          Overall              NaN                NaN
# Insulin Regular, Human  Novo Nordisk-Wa              NaN                NaN
# Insulin Regular, Human     Novo Nordisk              NaN                NaN
#
#                         Tot_Clms_2017  Tot_Benes_2017  \
# Gnrc_Name
# Insulin Glulisine             12635.0          3470.0
# Insulin Glulisine             12635.0          3470.0
# Insulin Glulisine             25100.0          7710.0
# Insulin Glulisine             25100.0          7710.0
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro              1217401.0        282797.0
# Insulin Lispro              1217401.0        282797.0
# Insulin Lispro                  119.0           110.0
# Insulin Lispro                  119.0           110.0
# Insulin Lispro              1512965.0        414218.0
# Insulin Lispro              1512965.0        414218.0
# Insulin Lispro                83023.0         23564.0
# Insulin Lispro                83023.0         23564.0
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Lispro                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart                    NaN             NaN
# Insulin Aspart              1271339.0        282388.0
# Insulin Aspart                    NaN             NaN
# Insulin Aspart              1271339.0        282388.0
# Insulin Aspart              2185868.0        545984.0
# Insulin Aspart                    NaN             NaN
# Insulin Aspart              2185868.0        545984.0
# Insulin Aspart                 8004.0          3153.0
# Insulin Aspart                 8004.0          3153.0
# Insulin Regular, Human         2609.0           745.0
# Insulin Regular, Human         2609.0           739.0
# Insulin Regular, Human       366577.0        101959.0
# Insulin Regular, Human       366577.0        101959.0
# Insulin Regular, Human        73118.0         14518.0
# Insulin Regular, Human        73118.0         14518.0
# Insulin Regular, Human        66294.0         13128.0
# Insulin Regular, Human        66294.0         13128.0
# Insulin Regular, Human       363075.0         90606.0
# Insulin Regular, Human        75781.0         21536.0
# Insulin Regular, Human       287294.0         71505.0
# Insulin Regular, Human            NaN             NaN
# Insulin Regular, Human            NaN             NaN
# Insulin Regular, Human            NaN             NaN
#
#                         Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  \
# Gnrc_Name
# Insulin Glulisine                             25.022690
# Insulin Glulisine                             25.022690
# Insulin Glulisine                             32.156073
# Insulin Glulisine                             32.156073
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                25.728293
# Insulin Lispro                                25.728293
# Insulin Lispro                                34.191917
# Insulin Lispro                                34.191917
# Insulin Lispro                                33.537697
# Insulin Lispro                                33.537697
# Insulin Lispro                                67.970772
# Insulin Lispro                                67.970772
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Lispro                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                      NaN
# Insulin Aspart                                27.640665
# Insulin Aspart                                      NaN
# Insulin Aspart                                27.640665
# Insulin Aspart                                35.228346
# Insulin Aspart                                      NaN
# Insulin Aspart                                35.228346
# Insulin Aspart                                33.581589
# Insulin Aspart                                33.581589
# Insulin Regular, Human                         3.835182
# Insulin Regular, Human                         3.835182
# Insulin Regular, Human                         9.737912
# Insulin Regular, Human                         9.737912
# Insulin Regular, Human                        70.642568
# Insulin Regular, Human                        70.642568
# Insulin Regular, Human                        91.136349
# Insulin Regular, Human                        91.136349
# Insulin Regular, Human                        11.769963
# Insulin Regular, Human                         2.847518
# Insulin Regular, Human                        14.123481
# Insulin Regular, Human                              NaN
# Insulin Regular, Human                              NaN
# Insulin Regular, Human                              NaN
#
#                         Avg_Spnd_Per_Clm_2017  Avg_Spnd_Per_Bene_2017  ...  \
# Gnrc_Name                                                              ...
# Insulin Glulisine                  713.280344             2597.203790  ...
# Insulin Glulisine                  713.280344             2597.203790  ...
# Insulin Glulisine                  758.771875             2470.191188  ...
# Insulin Glulisine                  758.771875             2470.191188  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                     488.358478             2102.314025  ...
# Insulin Lispro                     488.358478             2102.314025  ...
# Insulin Lispro                     695.618739              752.533000  ...
# Insulin Lispro                     695.618739              752.533000  ...
# Insulin Lispro                     719.983143             2629.797102  ...
# Insulin Lispro                     719.983143             2629.797102  ...
# Insulin Lispro                    1134.207972             3996.152966  ...
# Insulin Lispro                    1134.207972             3996.152966  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Lispro                            NaN                     NaN  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                     547.153690             2463.340600  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                     547.153690             2463.340600  ...
# Insulin Aspart                     700.888483             2806.034072  ...
# Insulin Aspart                            NaN                     NaN  ...
# Insulin Aspart                     700.888483             2806.034072  ...
# Insulin Aspart                     751.092260             1906.673787  ...
# Insulin Aspart                     751.092260             1906.673787  ...
# Insulin Regular, Human             743.883588             2605.090309  ...
# Insulin Regular, Human             743.883588             2626.241245  ...
# Insulin Regular, Human             192.782831              693.119312  ...
# Insulin Regular, Human             192.782831              693.119312  ...
# Insulin Regular, Human            1990.267726            10023.721971  ...
# Insulin Regular, Human            1990.267726            10023.721971  ...
# Insulin Regular, Human            1533.371279             7743.244634  ...
# Insulin Regular, Human            1533.371279             7743.244634  ...
# Insulin Regular, Human             188.146536              753.937967  ...
# Insulin Regular, Human              73.386727              258.233636  ...
# Insulin Regular, Human             218.417314              877.560784  ...
# Insulin Regular, Human                    NaN                     NaN  ...
# Insulin Regular, Human                    NaN                     NaN  ...
# Insulin Regular, Human                    NaN                     NaN  ...
#
#                         Tot_Spndng_2021  Tot_Dsg_Unts_2021  Tot_Clms_2021  \
# Gnrc_Name
# Insulin Glulisine            3769932.12          134030.00           3667
# Insulin Glulisine            3769932.12          134030.00           3667
# Insulin Glulisine           10338190.91          284742.00          10386
# Insulin Glulisine           10338190.91          284742.00          10386
# Insulin Lispro               2224714.69          161708.10          17009
# Insulin Lispro               2224714.69          161708.10          17009
# Insulin Lispro               6137620.19          352790.00          31839
# Insulin Lispro               6137620.19          352790.00          31839
# Insulin Lispro             435057237.32        16257949.20         647732
# Insulin Lispro             435057237.32        16257949.20         647732
# Insulin Lispro               7637030.74          217948.00          12355
# Insulin Lispro               7637030.74          217948.00          12355
# Insulin Lispro            1076261741.20        30566840.00        1209113
# Insulin Lispro            1076261741.20        30566840.00        1209113
# Insulin Lispro             178574228.92         2471033.00         123462
# Insulin Lispro             178574228.92         2471033.00         123462
# Insulin Lispro              70684051.90         4911637.84         221553
# Insulin Lispro              70684051.90         4911637.84         221553
# Insulin Lispro                976386.24           53115.00           3667
# Insulin Lispro                976386.24           53115.00           3667
# Insulin Aspart                                     NaN
# Insulin Aspart                                0.018805
# Insulin Aspart                                0.021064
# Insulin Aspart                                     NaN
# Insulin Aspart                                0.021895
# Insulin Aspart                                0.022360
# Insulin Aspart                                0.022360
# Insulin Regular, Human                        0.218834
# Insulin Regular, Human                        0.218834
# Insulin Regular, Human                       -0.001431
# Insulin Regular, Human                       -0.001431
# Insulin Regular, Human                        0.017117
# Insulin Regular, Human                        0.017117
# Insulin Regular, Human                        0.012391
# Insulin Regular, Human                        0.012391
# Insulin Regular, Human                        0.008109
# Insulin Regular, Human                        0.003131
# Insulin Regular, Human                        0.002185
# Insulin Regular, Human                        0.148267
# Insulin Regular, Human                        0.021860
# Insulin Regular, Human                        0.008056
#
# [50 rows x 45 columns]

# %%
#getting the column names for the medi_flitered_df to make the plotting easier 
medi_filtered_df.columns
# Out:
# Index(['Brnd_Name', 'Tot_Mftr', 'Mftr_Name', 'Tot_Spndng_2017',
#        'Tot_Dsg_Unts_2017', 'Tot_Clms_2017', 'Tot_Benes_2017',
#        'Avg_Spnd_Per_Dsg_Unt_Wghtd_2017', 'Avg_Spnd_Per_Clm_2017',
#        'Avg_Spnd_Per_Bene_2017', 'Outlier_Flag_2017', 'Tot_Spndng_2018',
#        'Tot_Dsg_Unts_2018', 'Tot_Clms_2018', 'Tot_Benes_2018',
#        'Avg_Spnd_Per_Dsg_Unt_Wghtd_2018', 'Avg_Spnd_Per_Clm_2018',
#        'Avg_Spnd_Per_Bene_2018', 'Outlier_Flag_2018', 'Tot_Spndng_2019',
#        'Tot_Dsg_Unts_2019', 'Tot_Clms_2019', 'Tot_Benes_2019',
#        'Avg_Spnd_Per_Dsg_Unt_Wghtd_2019', 'Avg_Spnd_Per_Clm_2019',
#        'Avg_Spnd_Per_Bene_2019', 'Outlier_Flag_2019', 'Tot_Spndng_2020',
#        'Tot_Dsg_Unts_2020', 'Tot_Clms_2020', 'Tot_Benes_2020',
#        'Avg_Spnd_Per_Dsg_Unt_Wghtd_2020', 'Avg_Spnd_Per_Clm_2020',
#        'Avg_Spnd_Per_Bene_2020', 'Outlier_Flag_2020', 'Tot_Spndng_2021',
#        'Tot_Dsg_Unts_2021', 'Tot_Clms_2021', 'Tot_Benes_2021',
#        'Avg_Spnd_Per_Dsg_Unt_Wghtd_2021', 'Avg_Spnd_Per_Clm_2021',
#        'Avg_Spnd_Per_Bene_2021', 'Outlier_Flag_2021',
#        'Chg_Avg_Spnd_Per_Dsg_Unt_20_21', 'CAGR_Avg_Spnd_Per_Dsg_Unt_17_21'],
#       dtype='object')

# %%
#Rename [Tot_Spndng_2019', 'Tot_Dsg_Unts_2019', 'Tot_Spndng_2020', 'Tot_Dsg_Unts_2020', 'Tot_Spndng_2021', 'Tot_Dsg_Unts_2021']

column_mapping = {
    'Tot_Spndng_2019': 'Total Spending 2019',
    'Tot_Dsg_Unts_2019': 'Total Dsg Units 2019',
    'Tot_Clms_2019 ': 'Total Claims 2019',
    'Tot_Spndng_2020': 'Total Spending 2020',
    'Tot_Dsg_Unts_2020': 'Total Dsg Units 2020',
    'Tot_Clms_2020': 'Total Claims 2020',
    'Tot_Spndng_2021': 'Total Spending 2021',
    'Tot_Dsg_Unts_2021': 'Total Dsg Units 2021',
    'Tot_Clms_2021': 'Total Claims 2020'
}

medi_filtered_df.rename(columns=column_mapping, inplace=True)

# columns_to_keep = ['Total Spending 2019', 'Total Dsg Units 2019', 'Total Spending 2020',
#                   'Total Dsg Units 2020', 'Total Claims 2020', 'Total Spending 2021', 'Total Dsg Units 2021', 'Total Claims 2020', 'Tot_Mftr', 'Mftr_Name']

# Select and keep only the specified columns
# medi_filtered_df = medi_filtered_df[columns_to_keep]
medi_filtered_df.head()
# Out:
#                          Brnd_Name  Tot_Mftr       Mftr_Name  Tot_Spndng_2017  \
# Gnrc_Name
# Insulin Glulisine           Apidra         1         Overall       9012297.15
# Insulin Glulisine           Apidra         1  Sanofi-Aventis       9012297.15
# Insulin Glulisine  Apidra Solostar         1         Overall      19045174.06
# Insulin Glulisine  Apidra Solostar         1  Sanofi-Aventis      19045174.06
# Insulin Lispro             Admelog         1         Overall              NaN
#
#                    Tot_Dsg_Unts_2017  Tot_Clms_2017  Tot_Benes_2017  \
# Gnrc_Name
# Insulin Glulisine           360165.0        12635.0          3470.0
# Insulin Glulisine           360165.0        12635.0          3470.0
# Insulin Glulisine           592273.0        25100.0          7710.0
# Insulin Glulisine           592273.0        25100.0          7710.0
# Insulin Lispro                   NaN            NaN             NaN
#
#                    Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# Gnrc_Name
# Insulin Glulisine                        25.022690             713.280344
# Insulin Glulisine                        25.022690             713.280344
# Insulin Glulisine                        32.156073             758.771875
# Insulin Glulisine                        32.156073             758.771875
# Insulin Lispro                                 NaN                    NaN
#
#                    Avg_Spnd_Per_Bene_2017  ...  Total Spending 2021  \
# Gnrc_Name                                  ...
# Insulin Glulisine             2597.203790  ...           3769932.12
# Insulin Glulisine             2597.203790  ...           3769932.12
# Insulin Glulisine             2470.191188  ...          10338190.91
# Insulin Glulisine             2470.191188  ...          10338190.91
# Insulin Lispro                        NaN  ...           2224714.69
#
#                    Total Dsg Units 2021  Total Claims 2020  Tot_Benes_2021  \
# Gnrc_Name
# Insulin Glulisine             134030.00               3667           931.0
# Insulin Glulisine             134030.00               3667           931.0
# Insulin Glulisine             284742.00              10386          2948.0
# Insulin Glulisine             284742.00              10386          2948.0
# Insulin Lispro                161708.10              17009          7148.0
#
#                    Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# Gnrc_Name
# Insulin Glulisine                        28.127525            1028.069845
# Insulin Glulisine                        28.127525            1028.069845
# Insulin Glulisine                        36.307222             995.396775
# Insulin Glulisine                        36.307222             995.396775
# Insulin Lispro                           13.757596             130.796325
#
#                    Avg_Spnd_Per_Bene_2021  Outlier_Flag_2021  \
# Gnrc_Name
# Insulin Glulisine             4049.336326                  0
# Insulin Glulisine             4049.336326                  0
# Insulin Glulisine             3506.849020                  0
# Insulin Glulisine             3506.849020                  0
# Insulin Lispro                 311.235967                  0
#
#                    Chg_Avg_Spnd_Per_Dsg_Unt_20_21  \
# Gnrc_Name
# Insulin Glulisine                        0.012566
# Insulin Glulisine                        0.012566
# Insulin Glulisine                        0.008155
# Insulin Glulisine                        0.008155
# Insulin Lispro                           0.013611
#
#                   CAGR_Avg_Spnd_Per_Dsg_Unt_17_21
# Gnrc_Name
# Insulin Glulisine                        0.029673
# Insulin Glulisine                        0.029673
# Insulin Glulisine                        0.030819
# Insulin Glulisine                        0.030819
# Insulin Lispro                          -0.166025
#
# [5 rows x 45 columns]

# %%
#Converting spending columns to user friendly option

columns_to_format = ['Total Spending 2019', 'Total Dsg Units 2019',
                     'Total Spending 2020', 'Total Dsg Units 2020',
                     'Total Spending 2021', 'Total Dsg Units 2021']

medi_filtered_df[columns_to_format] = medi_filtered_df[columns_to_format].astype(float)

# Apply the formatting to the specified columns
medi_filtered_df[columns_to_format] = medi_filtered_df[columns_to_format].applymap(lambda x: '{:.2f}'.format(x))

medi_filtered_df.head()
# Out:
# C:\Users\cfgoi\AppData\Local\Temp\ipykernel_23208\1301908306.py:10: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   medi_filtered_df[columns_to_format] = medi_filtered_df[columns_to_format].applymap(lambda x: '{:.2f}'.format(x))
#                          Brnd_Name  Tot_Mftr       Mftr_Name  Tot_Spndng_2017  \
# Gnrc_Name
# Insulin Glulisine           Apidra         1         Overall       9012297.15
# Insulin Glulisine           Apidra         1  Sanofi-Aventis       9012297.15
# Insulin Glulisine  Apidra Solostar         1         Overall      19045174.06
# Insulin Glulisine  Apidra Solostar         1  Sanofi-Aventis      19045174.06
# Insulin Lispro             Admelog         1         Overall              NaN
#
#                    Tot_Dsg_Unts_2017  Tot_Clms_2017  Tot_Benes_2017  \
# Gnrc_Name
# Insulin Glulisine           360165.0        12635.0          3470.0
# Insulin Glulisine           360165.0        12635.0          3470.0
# Insulin Glulisine           592273.0        25100.0          7710.0
# Insulin Glulisine           592273.0        25100.0          7710.0
# Insulin Lispro                   NaN            NaN             NaN
#
#                    Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# Gnrc_Name
# Insulin Glulisine                        25.022690             713.280344
# Insulin Glulisine                        25.022690             713.280344
# Insulin Glulisine                        32.156073             758.771875
# Insulin Glulisine                        32.156073             758.771875
# Insulin Lispro                                 NaN                    NaN
#
#                    Avg_Spnd_Per_Bene_2017  ...  Total Spending 2021  \
# Gnrc_Name                                  ...
# Insulin Glulisine             2597.203790  ...           3769932.12
# Insulin Glulisine             2597.203790  ...           3769932.12
# Insulin Glulisine             2470.191188  ...          10338190.91
# Insulin Glulisine             2470.191188  ...          10338190.91
# Insulin Lispro                        NaN  ...           2224714.69
#
#                    Total Dsg Units 2021  Total Claims 2020  Tot_Benes_2021  \
# Gnrc_Name
# Insulin Glulisine             134030.00               3667           931.0
# Insulin Glulisine             134030.00               3667           931.0
# Insulin Glulisine             284742.00              10386          2948.0
# Insulin Glulisine             284742.00              10386          2948.0
# Insulin Lispro                161708.10              17009          7148.0
#
#                    Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# Gnrc_Name
# Insulin Glulisine                        28.127525            1028.069845
# Insulin Glulisine                        28.127525            1028.069845
# Insulin Glulisine                        36.307222             995.396775
# Insulin Glulisine                        36.307222             995.396775
# Insulin Lispro                           13.757596             130.796325
#
#                    Avg_Spnd_Per_Bene_2021  Outlier_Flag_2021  \
# Gnrc_Name
# Insulin Glulisine             4049.336326                  0
# Insulin Glulisine             4049.336326                  0
# Insulin Glulisine             3506.849020                  0
# Insulin Glulisine             3506.849020                  0
# Insulin Lispro                 311.235967                  0
#
#                    Chg_Avg_Spnd_Per_Dsg_Unt_20_21  \
# Gnrc_Name
# Insulin Glulisine                        0.012566
# Insulin Glulisine                        0.012566
# Insulin Glulisine                        0.008155
# Insulin Glulisine                        0.008155
# Insulin Lispro                           0.013611
#
#                   CAGR_Avg_Spnd_Per_Dsg_Unt_17_21
# Gnrc_Name
# Insulin Glulisine                        0.029673
# Insulin Glulisine                        0.029673
# Insulin Glulisine                        0.030819
# Insulin Glulisine                        0.030819
# Insulin Lispro                          -0.166025
#
# [5 rows x 45 columns]

# %%
#Calculating and plotting the mean for spending for years 2019-2021



import numpy as np

# Replace 'nan' with NaN (missing values)
medi_filtered_df = medi_filtered_df.replace('nan', np.nan)

# Specify the columns to convert to numeric
numeric_columns = ['Total Spending 2019',
                   'Total Spending 2020', 
                   'Total Spending 2021']

# Attempt to convert the columns to numeric
medi_filtered_df[numeric_columns] = medi_filtered_df[numeric_columns].apply(pd.to_numeric, errors='coerce')

#import matplotlib
import matplotlib.pyplot as plt

columns_to_include = ['Total Spending 2019', 
                   'Total Spending 2020', 
                   'Total Spending 2021',]

# list with claims included ['Total Spending 2019', 'Total Dsg Units 2019', 'Total Claims 2019', \
#                    'Total Spending 2020', 'Total Dsg Units 2020', 'Total Claims 2020',\
#                    'Total Spending 2021', 'Total Dsg Units 2021', 'Total Claims 2020']

# Create DF for only the selected columns
medi_filtered_2019_2021 = medi_filtered_df[columns_to_include]

# Calculating the mean for each column
medi_mean_values = medi_filtered_2019_2021.mean()

#Create bar plot for the mean values

plt.figure(figsize=(12, 6))
medi_mean_values.plot(kind='bar')
plt.title('Mean Spending Values (in dollars) for Insulin - Years 2019-2021')
plt.xlabel('Columns')
plt.ylabel('Mean Value')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Resources/mean_values_spending_plot.png')
plt.show()

# %%
#Calculating and plotting the mean for dosages for  years 2019-2021

import numpy as np

# Replace 'nan' with NaN (missing values)
medi_filtered_df = medi_filtered_df.replace('nan', np.nan)

# Specify the columns to convert to numeric
numeric_columns_dsg = ['Total Dsg Units 2019',
                   'Total Dsg Units 2020',
                   'Total Dsg Units 2021']

# Attempt to convert the columns to numeric
medi_filtered_df[numeric_columns_dsg] = medi_filtered_df[numeric_columns_dsg].apply(pd.to_numeric, errors='coerce')

#import matplotlib
import matplotlib.pyplot as plt

columns_to_include_dsg = ['Total Dsg Units 2019',
                   'Total Dsg Units 2020',
                   'Total Dsg Units 2021']

# list with claims included ['Total Spending 2019', 'Total Dsg Units 2019', 'Total Claims 2019', \
#                    'Total Spending 2020', 'Total Dsg Units 2020', 'Total Claims 2020',\
#                    'Total Spending 2021', 'Total Dsg Units 2021', 'Total Claims 2020']

# Create DF for only the selected columns
medi_filtered_2019_2021 = medi_filtered_df[columns_to_include_dsg]

# Calculating the mean for each column
mean_values = medi_filtered_2019_2021.mean()

#Create bar plot for the mean values

plt.figure(figsize=(12, 6))
mean_values.plot(kind='bar', color = 'g')
plt.title('Mean dosage units for Insulin from Medicare - 2019-2021')
plt.xlabel('Columns')
plt.ylabel('Mean Value')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.tight_layout()

plt.savefig('Resources/mean_values_dosages_plot.png')
plt.show()

# %%
#calculating the Median for 2019-2020

# Define the columns you want to include
columns_to_include_median = ['Total Dsg Units 2019',
                   'Total Dsg Units 2020',
                   'Total Dsg Units 2021','Total Spending 2019',
                   'Total Spending 2020', 
                   'Total Spending 2021']

median_columns_spnd = ['Total Spending 2019',
                   'Total Spending 2020', 
                   'Total Spending 2021']

median_columns_dsg = ['Total Dsg Units 2019',
                   'Total Dsg Units 2020',
                   'Total Dsg Units 2021']

# Create DF for spend and one for dsg 
median_filtered_spnd = medi_filtered_df[median_columns_spnd]

median_filtered_dsg = medi_filtered_df[median_columns_dsg]

# Calculate the median for each column
median_values_spnd = median_filtered_spnd.median()

median_filtered_dsg = median_filtered_dsg.median()

# Display the median values
print("Median Values for the Selected Columns:")
print(median_values_spnd)

print("Median Values for the Selected Columns:")
print(median_filtered_dsg)
# Out:
# Median Values for the Selected Columns:
# Total Spending 2019    2.192407e+07
# Total Spending 2020    2.157053e+07
# Total Spending 2021    1.982417e+07
# dtype: float64
# Median Values for the Selected Columns:
# Total Dsg Units 2019    1456717.90
# Total Dsg Units 2020    1289875.03
# Total Dsg Units 2021    1216380.00
# dtype: float64

# %%
#Plotting the Median for spend 2019-2020


# Create a bar plot for the median values spend
plt.figure(figsize=(12, 6))
median_values_spnd.plot(kind='bar', color = 'purple')
plt.title('Median Values for Medicare spend on Insulin Years 2019-2021')
plt.xlabel('Columns')
plt.ylabel('Median Value')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.tight_layout()

# Save the plot as an image (e.g., in PNG format)
plt.savefig('Resources/median_values_plot_spnd.png')

# Show the plot (optional)
plt.show()

# %%
#Plotting the Median for dosage 2019-2020


# Create a bar plot for the median values spend
plt.figure(figsize=(12, 6))
median_filtered_dsg.plot(kind='bar', color = 'magenta')
plt.title('Median Values Medicare Insulin Dosages - 2019-2021')
plt.xlabel('Columns')
plt.ylabel('Median Value')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.tight_layout()

# Save the plot as an image (e.g., in PNG format)
plt.savefig('Resources/median_values_plot_dsg.png')

# Show the plot (optional)
plt.show()

# %%
#Plotting standard deviation

import matplotlib.pyplot as plt

# Lists for columns for standard deviation by spend and dosage
stddev_columns_spnd = ['Total Spending 2019',
                      'Total Spending 2020',
                      'Total Spending 2021']

stddev_columns_dsg = ['Total Dsg Units 2019',
                      'Total Dsg Units 2020',
                      'Total Dsg Units 2021']

# Extract the columns of interest from your DataFrame
stddev_spnd = medi_filtered_df[stddev_columns_spnd].apply(pd.to_numeric, errors='coerce')
stddev_dsg = medi_filtered_df[stddev_columns_dsg].apply(pd.to_numeric, errors='coerce')

# Calculate standard deviation for spending and dosage
stddev_spnd_values = stddev_spnd.std()
stddev_dsg_values = stddev_dsg.std()

# Create line plots for standard deviation
plt.figure(figsize=(12, 6))

# Line plot for standard deviation of spending
plt.plot(stddev_spnd_values.index, stddev_spnd_values.values, label='Standard Deviation of Spending', marker='o')

# Line plot for standard deviation of dosage
plt.plot(stddev_dsg_values.index, stddev_dsg_values.values, label='Standard Deviation of Dosage', marker='o')

plt.title('Standard Deviation for Spending and Dosage (2019-2021)')
plt.xlabel('Year')
plt.ylabel('Standard Deviation')
plt.legend()
plt.ticklabel_format(style='plain', axis='y')
plt.grid(True)
plt.tight_layout()

# Save the plot as an image (e.g., in PNG format)
plt.savefig('Resources/standarddeviation_values_plot.png')
plt.show()

# Print the standard deviations
print('Standard Deviation of Spending:')
print(stddev_spnd_values)
print('\nStandard Deviation of Dosage:')
print(stddev_dsg_values)
# Out:
# Standard Deviation of Spending:
# Total Spending 2019    4.938191e+08
# Total Spending 2020    4.230649e+08
# Total Spending 2021    4.110872e+08
# dtype: float64
#
# Standard Deviation of Dosage:
# Total Dsg Units 2019    1.381108e+07
# Total Dsg Units 2020    1.166863e+07
# Total Dsg Units 2021    1.118121e+07
# dtype: float64

# %%
#Plot the top manufacturers of insulin between 2019 and 2021

# Who produced and distributed the most insulin through medicare from 
# 2019-2021? Who are the top 5 insulin producers? 

# Filter out rows containing 'overall' in 'Mftr_Name' column
medi_filtered_manufacture_df = medi_filtered_df[~medi_filtered_df['Mftr_Name'].str.contains('overall', case=False)]

# Filter the DataFrame for the years 2019, 2020, and 2021
years_to_include = ['Total Dsg Units 2019',
                   'Total Dsg Units 2020',
                   'Total Dsg Units 2021']
mftr_filtered_df = medi_filtered_df[['Mftr_Name'] + years_to_include]

# Group the data by manufacturer and calculate the total insulin production for each manufacturer
medi_grouped_df = mftr_filtered_df.groupby('Mftr_Name')[years_to_include].sum()

# Calculate the total production for each manufacturer
medi_grouped_df['Total_Production'] = medi_grouped_df.sum(axis=1)

# Sort the manufacturers by total production in descending order to identify the top producers
insulin_top_mftr = medi_grouped_df.sort_values(by='Total_Production', ascending=False).head(10)

# Create a bar chart to visualize the top insulin producers
plt.figure(figsize=(12, 10))
insulin_top_mftr['Total_Production'].plot(kind='bar')
plt.title('Top Insulin Producers (2019-2021)')
plt.xlabel('Manufacturer')
plt.ylabel('Total Production')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.tight_layout()

# Save the plot as an image 
plt.savefig('Resources/top_insulin_mftrs.png')

# Add a legend to the chart
plt.legend()
plt.show()

# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np
#import pandas as pd

# %%
# Read file into DataFrame
medicare_insulin = pd.read_csv('Resources/Medicare_Part_D_Spending_by_Drug_2021.csv')
#medi_df.head(20)
medicare_insulin.head()
# Out:
#                        Brnd_Name             Gnrc_Name  Tot_Mftr  \
# 0       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 1       1st Tier Unifine Pentips  Pen Needle, Diabetic         1
# 2  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 3  1st Tier Unifine Pentips Plus  Pen Needle, Diabetic         1
# 4                       Abacavir      Abacavir Sulfate         7
#
#          Mftr_Name  Tot_Spndng_2017  Tot_Dsg_Unts_2017  Tot_Clms_2017  \
# 0          Overall        217938.04          1014318.0         8595.0
# 1  Owen Mumford Us        217938.04          1014318.0         8595.0
# 2          Overall        402124.68          1850703.0        15403.0
# 3  Owen Mumford Us        402124.68          1850703.0        15403.0
# 4          Overall      13386250.08          3189707.0        48283.0
#
#    Tot_Benes_2017  Avg_Spnd_Per_Dsg_Unt_Wghtd_2017  Avg_Spnd_Per_Clm_2017  \
# 0          3025.0                         0.216105              25.356375
# 1          3025.0                         0.216105              25.356375
# 2          5967.0                         0.217359              26.106906
# 3          5967.0                         0.217359              26.106906
# 4          8090.0                         4.298589             277.245616
#
#    ...  Tot_Spndng_2021  Tot_Dsg_Unts_2021  Tot_Clms_2021  Tot_Benes_2021  \
# 0  ...        102280.76           459384.0           3708          1313.0
# 1  ...        102280.76           459384.0           3708          1313.0
# 2  ...        131927.33           566872.0           4564          1766.0
# 3  ...        131927.33           566872.0           4564          1766.0
# 4  ...       7038593.83          2501447.0          30540          4254.0
#
#    Avg_Spnd_Per_Dsg_Unt_Wghtd_2021  Avg_Spnd_Per_Clm_2021  \
# 0                         0.223001              27.583808
# 1                         0.223001              27.583808
# 2                         0.232812              28.906076
# 3                         0.232812              28.906076
# 4                         3.187698             230.471311
#
#    Avg_Spnd_Per_Bene_2021  Outlier_Flag_2021  Chg_Avg_Spnd_Per_Dsg_Unt_20_21  \
# 0               77.898522                  0                        0.024346
# 1               77.898522                  0                        0.024346
# 2               74.704037                  0                        0.159124
# 3               74.704037                  0                        0.159124
# 4             1654.582471                  0                       -0.087066
#
#    CAGR_Avg_Spnd_Per_Dsg_Unt_17_21
# 0                         0.007885
# 1                         0.007885
# 2                         0.017317
# 3                         0.017317
# 4                        -0.072022
#
# [5 rows x 46 columns]

# %%
# Define the names to filter in the 'Gnrc_Name' column
medi_names_to_filter = ['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']
# Define relevant columns for the year 2019
medi_relevant_columns_2019 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2019', 'Tot_Dsg_Unts_2019']
# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]
# Select relevant columns for the year 2019
medi_result_df_2019 = filtered_df[medi_relevant_columns_2019]
# Display the result DataFrame
print(medi_result_df_2019)
medi_result_df_2019.head()
#medi = medi_result_df_2019['Mftr_Name'].value('Tot_Spndng_2019')
#medi
# Out:
#                    Gnrc_Name        Mftr_Name  Tot_Spndng_2019  \
# 243           Insulin Lispro   Sanofi-Aventis     2.076727e+06
# 245           Insulin Lispro   Sanofi-Aventis     5.632924e+06
# 271   Insulin Regular, Human  Mannkind Corpor     7.000875e+06
# 772        Insulin Glulisine   Sanofi-Aventis     5.352751e+06
# 774        Insulin Glulisine   Sanofi-Aventis     1.401256e+07
# 5771          Insulin Lispro  Eli Lilly & Co.     5.492364e+08
# 5773          Insulin Lispro  Eli Lilly & Co.     4.230471e+06
# 5775          Insulin Lispro  Eli Lilly & Co.     1.218056e+09
# 5777          Insulin Lispro  Eli Lilly & Co.     1.402135e+08
# 5815  Insulin Regular, Human  Eli Lilly & Co.     6.623255e+07
# 5817  Insulin Regular, Human  Eli Lilly & Co.     1.077373e+08
# 5819  Insulin Regular, Human  Eli Lilly & Co.     2.067820e+08
# 6211          Insulin Aspart     Novo Nordisk              NaN
# 6213          Insulin Aspart     Novo Nordisk              NaN
# 6215          Insulin Aspart     Novo Nordisk              NaN
# 6221          Insulin Lispro  Eli Lilly & Co.     8.870538e+06
# 6223          Insulin Lispro  Eli Lilly & Co.              NaN
# 6225          Insulin Lispro  Eli Lilly & Co.     2.192407e+07
# 8939  Insulin Regular, Human  Novo Nordisk-Wa     4.525436e+06
# 8940  Insulin Regular, Human     Novo Nordisk     5.640745e+07
# 8942  Insulin Regular, Human  Novo Nordisk-Wa              NaN
# 8943  Insulin Regular, Human     Novo Nordisk              NaN
# 8945          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8946          Insulin Aspart     Novo Nordisk     6.585012e+08
# 8948          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8949          Insulin Aspart     Novo Nordisk     1.843976e+09
# 8957          Insulin Aspart     Novo Nordisk     6.959634e+06
#
#       Tot_Dsg_Unts_2019
# 243        1.200337e+05
# 245        1.248402e+06
# 271        9.778800e+05
# 772        1.926600e+05
# 774        3.895440e+05
# 5771       2.068148e+07
# 5773       1.216120e+05
# 5775       3.493181e+07
# 5777       1.976476e+06
# 5815       6.641352e+06
# 5817       1.456718e+06
# 5819       2.203220e+06
# 6211                NaN
# 6213                NaN
# 6215                NaN
# 6221       6.228340e+05
# 6223                NaN
# 6225       1.212082e+06
# 8939       1.605562e+06
# 8940       4.008605e+06
# 8942                NaN
# 8943                NaN
# 8945                NaN
# 8946       2.242928e+07
# 8948                NaN
# 8949       4.916059e+07
# 8957       1.955080e+05
#                   Gnrc_Name        Mftr_Name  Tot_Spndng_2019  \
# 243          Insulin Lispro   Sanofi-Aventis       2076727.30
# 245          Insulin Lispro   Sanofi-Aventis       5632924.42
# 271  Insulin Regular, Human  Mannkind Corpor       7000874.53
# 772       Insulin Glulisine   Sanofi-Aventis       5352750.90
# 774       Insulin Glulisine   Sanofi-Aventis      14012558.62
#
#      Tot_Dsg_Unts_2019
# 243         120033.714
# 245        1248401.999
# 271         977880.000
# 772         192660.000
# 774         389544.000

# %%
#Total Spending by Manuf
medi_2019_result = medi_result_df_2019.groupby('Mftr_Name').sum()
medi_2019_result
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2019  Tot_Dsg_Unts_2019
# Mftr_Name
# Eli Lilly & Co.     2.323283e+09       6.984759e+07
# Mannkind Corpor     7.000875e+06       9.778800e+05
# Novo Nordisk        2.565845e+09       7.579399e+07
# Novo Nordisk-Wa     4.525436e+06       1.605562e+06
# Sanofi-Aventis      2.707496e+07       1.950640e+06

# %%
# Configure plot, ,6figsize, title, and axis labels
fig1 = medi_2019_result['Tot_Spndng_2019'].plot(kind="bar", facecolor="red", figsize=(8,6),
                             title = "Total Spending",
                             xlabel = "Manufacturer",
                             ylabel = "Price")

# Configure x-tick rotation
xticklabels = medi_2019_result.index

fig1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)

# Show plot
plt.show()

# %%
# Define the names to filter in the 'Gnrc_Name' column
medi_names_to_filter = ['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']
# Define relevant columns for the year 2019
medi_relevant_columns_2019 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2019', 'Tot_Dsg_Unts_2019']
# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]
# Select relevant columns for the year 2019
medi_result_df_2019 = filtered_df[medi_relevant_columns_2019]
# Display the result DataFrame
print(medi_result_df_2019)
medi_result_df_2019.head()
# Out:
#                    Gnrc_Name        Mftr_Name  Tot_Spndng_2019  \
# 243           Insulin Lispro   Sanofi-Aventis     2.076727e+06
# 245           Insulin Lispro   Sanofi-Aventis     5.632924e+06
# 271   Insulin Regular, Human  Mannkind Corpor     7.000875e+06
# 772        Insulin Glulisine   Sanofi-Aventis     5.352751e+06
# 774        Insulin Glulisine   Sanofi-Aventis     1.401256e+07
# 5771          Insulin Lispro  Eli Lilly & Co.     5.492364e+08
# 5773          Insulin Lispro  Eli Lilly & Co.     4.230471e+06
# 5775          Insulin Lispro  Eli Lilly & Co.     1.218056e+09
# 5777          Insulin Lispro  Eli Lilly & Co.     1.402135e+08
# 5815  Insulin Regular, Human  Eli Lilly & Co.     6.623255e+07
# 5817  Insulin Regular, Human  Eli Lilly & Co.     1.077373e+08
# 5819  Insulin Regular, Human  Eli Lilly & Co.     2.067820e+08
# 6211          Insulin Aspart     Novo Nordisk              NaN
# 6213          Insulin Aspart     Novo Nordisk              NaN
# 6215          Insulin Aspart     Novo Nordisk              NaN
# 6221          Insulin Lispro  Eli Lilly & Co.     8.870538e+06
# 6223          Insulin Lispro  Eli Lilly & Co.              NaN
# 6225          Insulin Lispro  Eli Lilly & Co.     2.192407e+07
# 8939  Insulin Regular, Human  Novo Nordisk-Wa     4.525436e+06
# 8940  Insulin Regular, Human     Novo Nordisk     5.640745e+07
# 8942  Insulin Regular, Human  Novo Nordisk-Wa              NaN
# 8943  Insulin Regular, Human     Novo Nordisk              NaN
# 8945          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8946          Insulin Aspart     Novo Nordisk     6.585012e+08
# 8948          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8949          Insulin Aspart     Novo Nordisk     1.843976e+09
# 8957          Insulin Aspart     Novo Nordisk     6.959634e+06
#
#       Tot_Dsg_Unts_2019
# 243        1.200337e+05
# 245        1.248402e+06
# 271        9.778800e+05
# 772        1.926600e+05
# 774        3.895440e+05
# 5771       2.068148e+07
# 5773       1.216120e+05
# 5775       3.493181e+07
# 5777       1.976476e+06
# 5815       6.641352e+06
# 5817       1.456718e+06
# 5819       2.203220e+06
# 6211                NaN
# 6213                NaN
# 6215                NaN
# 6221       6.228340e+05
# 6223                NaN
# 6225       1.212082e+06
# 8939       1.605562e+06
# 8940       4.008605e+06
# 8942                NaN
# 8943                NaN
# 8945                NaN
# 8946       2.242928e+07
# 8948                NaN
# 8949       4.916059e+07
# 8957       1.955080e+05
#                   Gnrc_Name        Mftr_Name  Tot_Spndng_2019  \
# 243          Insulin Lispro   Sanofi-Aventis       2076727.30
# 245          Insulin Lispro   Sanofi-Aventis       5632924.42
# 271  Insulin Regular, Human  Mannkind Corpor       7000874.53
# 772       Insulin Glulisine   Sanofi-Aventis       5352750.90
# 774       Insulin Glulisine   Sanofi-Aventis      14012558.62
#
#      Tot_Dsg_Unts_2019
# 243         120033.714
# 245        1248401.999
# 271         977880.000
# 772         192660.000
# 774         389544.000

# %%
#Total Dosage by Manuf
medi_2019_result = medi_result_df_2019.groupby('Mftr_Name').sum()
medi_2019_result
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2019  Tot_Dsg_Unts_2019
# Mftr_Name
# Eli Lilly & Co.     2.323283e+09       6.984759e+07
# Mannkind Corpor     7.000875e+06       9.778800e+05
# Novo Nordisk        2.565845e+09       7.579399e+07
# Novo Nordisk-Wa     4.525436e+06       1.605562e+06
# Sanofi-Aventis      2.707496e+07       1.950640e+06

# %%
# Configure plot, ,6figsize, title, and axis labels
fig1 = medi_2019_result['Tot_Dsg_Unts_2019'].plot(kind="bar", facecolor="red", figsize=(8,6),
                             title = "Total Dosage",
                             xlabel = "Manufacturer",
                             ylabel = "Dosage")

# Configure x-tick rotation
xticklabels = medi_2019_result.index
fig1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)
# Show plot
plt.show()

# %%
#Avg cost per dosage by manuf Tot_Spndng_2019/Tot_Dsg_Unts_2019

medi_2019_result['Avg_Cost_Per_Dsg_2019'] = medi_2019_result['Tot_Spndng_2019']/medi_2019_result['Tot_Dsg_Unts_2019']
medi_2019_result
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2019  Tot_Dsg_Unts_2019  Avg_Cost_Per_Dsg_2019
# Mftr_Name
# Eli Lilly & Co.     2.323283e+09       6.984759e+07              33.262180
# Mannkind Corpor     7.000875e+06       9.778800e+05               7.159237
# Novo Nordisk        2.565845e+09       7.579399e+07              33.852877
# Novo Nordisk-Wa     4.525436e+06       1.605562e+06               2.818599
# Sanofi-Aventis      2.707496e+07       1.950640e+06              13.880042

# %%
# Configure plot, ,6figsize, title, and axis labels
fig1 = medi_2019_result['Avg_Cost_Per_Dsg_2019'].plot(kind="bar", facecolor="purple", figsize=(8,6),
                             title = "Average Cost Per Dosage 2019",
                             xlabel = "Manufacturer",
                             ylabel = "Avg Cost")

# Configure x-tick rotation
xticklabels = medi_2019_result.index
plt.ticklabel_format(style = 'plain', axis='y')
fig1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)
# Show plot
plt.show()

# %%
# Define the names to filter in the 'Gnrc_Name' column
medi_names_to_filter = ['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']
# Define relevant columns for the year 2020
medi_relevant_columns_2020 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2020', 'Tot_Dsg_Unts_2020']
# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]
# Select relevant columns for the year 2020
medi_result_df_2020 = filtered_df[medi_relevant_columns_2020]
# Display the result DataFrame
print(medi_result_df_2020)
medi_result_df_2020.head()
# Out:
#                    Gnrc_Name        Mftr_Name  Tot_Spndng_2020  \
# 243           Insulin Lispro   Sanofi-Aventis     2.461450e+06
# 245           Insulin Lispro   Sanofi-Aventis     5.785748e+06
# 271   Insulin Regular, Human  Mannkind Corpor     8.007830e+06
# 772        Insulin Glulisine   Sanofi-Aventis     4.528780e+06
# 774        Insulin Glulisine   Sanofi-Aventis     1.226855e+07
# 5771          Insulin Lispro  Eli Lilly & Co.     4.492513e+08
# 5773          Insulin Lispro  Eli Lilly & Co.     6.145479e+06
# 5775          Insulin Lispro  Eli Lilly & Co.     1.053916e+09
# 5777          Insulin Lispro  Eli Lilly & Co.     1.545332e+08
# 5815  Insulin Regular, Human  Eli Lilly & Co.     6.390659e+07
# 5817  Insulin Regular, Human  Eli Lilly & Co.     9.552538e+07
# 5819  Insulin Regular, Human  Eli Lilly & Co.     2.318727e+08
# 6211          Insulin Aspart     Novo Nordisk     1.178440e+07
# 6213          Insulin Aspart     Novo Nordisk     3.087250e+07
# 6215          Insulin Aspart     Novo Nordisk     1.366072e+05
# 6221          Insulin Lispro  Eli Lilly & Co.     5.575553e+07
# 6223          Insulin Lispro  Eli Lilly & Co.     3.252693e+05
# 6225          Insulin Lispro  Eli Lilly & Co.     1.416218e+08
# 8939  Insulin Regular, Human  Novo Nordisk-Wa     4.121791e+06
# 8940  Insulin Regular, Human     Novo Nordisk     5.041295e+07
# 8942  Insulin Regular, Human  Novo Nordisk-Wa     1.250836e+05
# 8943  Insulin Regular, Human     Novo Nordisk     2.052605e+06
# 8945          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8946          Insulin Aspart     Novo Nordisk     5.869778e+08
# 8948          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8949          Insulin Aspart     Novo Nordisk     1.844084e+09
# 8957          Insulin Aspart     Novo Nordisk     8.204522e+06
#
#       Tot_Dsg_Unts_2020
# 243        1.813510e+05
# 245        3.392590e+05
# 271        1.036929e+06
# 772        1.630320e+05
# 774        3.406650e+05
# 5771       1.724181e+07
# 5773       1.787170e+05
# 5775       3.057358e+07
# 5777       2.184844e+06
# 5815       6.494117e+06
# 5817       1.289875e+06
# 5819       2.466670e+06
# 6211       8.014670e+05
# 6213       1.665054e+06
# 6215       7.929000e+03
# 6221       3.938873e+06
# 6223       1.798200e+04
# 6225       7.819461e+06
# 8939       1.452663e+06
# 8940       3.551676e+06
# 8942       4.338600e+04
# 8943       1.149460e+05
# 8945                NaN
# 8946       1.994095e+07
# 8948                NaN
# 8949       4.857480e+07
# 8957       2.274700e+05
#                   Gnrc_Name        Mftr_Name  Tot_Spndng_2020  \
# 243          Insulin Lispro   Sanofi-Aventis       2461450.03
# 245          Insulin Lispro   Sanofi-Aventis       5785747.56
# 271  Insulin Regular, Human  Mannkind Corpor       8007830.06
# 772       Insulin Glulisine   Sanofi-Aventis       4528780.01
# 774       Insulin Glulisine   Sanofi-Aventis      12268554.96
#
#      Tot_Dsg_Unts_2020
# 243           181351.0
# 245           339259.0
# 271          1036929.0
# 772           163032.0
# 774           340665.0

# %%
#Total Dosage by Manuf 2020
medi_2020_result = medi_result_df_2020.groupby('Mftr_Name').sum()
medi_2020_result
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2020  Tot_Dsg_Unts_2020
# Mftr_Name
# Eli Lilly & Co.     2.252853e+09       7.220593e+07
# Mannkind Corpor     8.007830e+06       1.036929e+06
# Novo Nordisk        2.534526e+09       7.488429e+07
# Novo Nordisk-Wa     4.246875e+06       1.496049e+06
# Sanofi-Aventis      2.504453e+07       1.024307e+06

# %%
#Avg cost per dosage by manuf Tot_Spndng_2020/Tot_Dsg_Unts_2020

medi_2020_result['Avg_Cost_Per_Dsg_2020'] = medi_2020_result['Tot_Spndng_2020']/medi_2020_result['Tot_Dsg_Unts_2020']
medi_2020_result
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2020  Tot_Dsg_Unts_2020  Avg_Cost_Per_Dsg_2020
# Mftr_Name
# Eli Lilly & Co.     2.252853e+09       7.220593e+07              31.200388
# Mannkind Corpor     8.007830e+06       1.036929e+06               7.722641
# Novo Nordisk        2.534526e+09       7.488429e+07              33.845892
# Novo Nordisk-Wa     4.246875e+06       1.496049e+06               2.838728
# Sanofi-Aventis      2.504453e+07       1.024307e+06              24.450221

# %%
# Configure plot, ,6figsize, title, and axis labels
fig1 = medi_2020_result['Avg_Cost_Per_Dsg_2020'].plot(kind="bar", facecolor="purple", figsize=(8,6),
                             title = "Average Cost Per Dosage 2020",
                             xlabel = "Manufacturer",
                             ylabel = "Avg Cost")

# Configure x-tick rotation
xticklabels = medi_2020_result.index
plt.ticklabel_format(style = 'plain', axis='y')
fig1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)
# Show plot
plt.show()

# %%
# Define the names to filter in the 'Gnrc_Name' column
medi_names_to_filter = ['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']
# Define relevant columns for the year 2021
medi_relevant_columns_2021 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2021', 'Tot_Dsg_Unts_2021']
# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]
# Select relevant columns for the year 2021
medi_result_df_2021 = filtered_df[medi_relevant_columns_2021]
# Display the result DataFrame
print(medi_result_df_2021)
medi_result_df_2021.head()
# Out:
#                    Gnrc_Name        Mftr_Name  Tot_Spndng_2021  \
# 243           Insulin Lispro   Sanofi-Aventis     2.224715e+06
# 245           Insulin Lispro   Sanofi-Aventis     6.137620e+06
# 271   Insulin Regular, Human  Mannkind Corpor     1.039369e+07
# 772        Insulin Glulisine   Sanofi-Aventis     3.769932e+06
# 774        Insulin Glulisine   Sanofi-Aventis     1.033819e+07
# 5771          Insulin Lispro  Eli Lilly & Co.     4.350572e+08
# 5773          Insulin Lispro  Eli Lilly & Co.     7.637031e+06
# 5775          Insulin Lispro  Eli Lilly & Co.     1.076262e+09
# 5777          Insulin Lispro  Eli Lilly & Co.     1.785742e+08
# 5815  Insulin Regular, Human  Eli Lilly & Co.     6.092082e+07
# 5817  Insulin Regular, Human  Eli Lilly & Co.     8.820523e+07
# 5819  Insulin Regular, Human  Eli Lilly & Co.     2.493683e+08
# 6211          Insulin Aspart     Novo Nordisk     1.982417e+07
# 6213          Insulin Aspart     Novo Nordisk     5.999348e+07
# 6215          Insulin Aspart     Novo Nordisk     3.643753e+05
# 6221          Insulin Lispro  Eli Lilly & Co.     7.068405e+07
# 6223          Insulin Lispro  Eli Lilly & Co.     9.763862e+05
# 6225          Insulin Lispro  Eli Lilly & Co.     1.896275e+08
# 8939  Insulin Regular, Human  Novo Nordisk-Wa     3.178184e+06
# 8940  Insulin Regular, Human     Novo Nordisk     4.504622e+07
# 8942  Insulin Regular, Human  Novo Nordisk-Wa     1.998935e+05
# 8943  Insulin Regular, Human     Novo Nordisk     8.286203e+06
# 8945          Insulin Aspart  Novo Nordisk-Wa     8.242499e+05
# 8946          Insulin Aspart     Novo Nordisk     5.455735e+08
# 8948          Insulin Aspart  Novo Nordisk-Wa     9.625774e+05
# 8949          Insulin Aspart     Novo Nordisk     1.816712e+09
# 8957          Insulin Aspart     Novo Nordisk     9.825961e+06
#
#       Tot_Dsg_Unts_2021
# 243        1.617081e+05
# 245        3.527900e+05
# 271        1.216380e+06
# 772        1.340300e+05
# 774        2.847420e+05
# 5771       1.625795e+07
# 5773       2.179480e+05
# 5775       3.056684e+07
# 5777       2.471033e+06
# 5815       6.291980e+06
# 5817       1.166660e+06
# 5819       2.604695e+06
# 6211       1.350051e+06
# 6213       3.195601e+06
# 6215       2.046100e+04
# 6221       4.911638e+06
# 6223       5.311500e+04
# 6225       1.027291e+07
# 8939       1.102257e+06
# 8940       3.161736e+06
# 8942       6.785100e+04
# 8943       4.603196e+05
# 8945       1.123150e+05
# 8946       1.832066e+07
# 8948       1.676960e+05
# 8949       4.728998e+07
# 8957       2.678290e+05
#                   Gnrc_Name        Mftr_Name  Tot_Spndng_2021  \
# 243          Insulin Lispro   Sanofi-Aventis       2224714.69
# 245          Insulin Lispro   Sanofi-Aventis       6137620.19
# 271  Insulin Regular, Human  Mannkind Corpor      10393693.26
# 772       Insulin Glulisine   Sanofi-Aventis       3769932.12
# 774       Insulin Glulisine   Sanofi-Aventis      10338190.91
#
#      Tot_Dsg_Unts_2021
# 243           161708.1
# 245           352790.0
# 271          1216380.0
# 772           134030.0
# 774           284742.0

# %%
#Total Dosage by Manuf 2021
medi_2021_result = medi_result_df_2021.groupby('Mftr_Name').sum()
medi_2021_result
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2021  Tot_Dsg_Unts_2021
# Mftr_Name
# Eli Lilly & Co.     2.357312e+09       7.481477e+07
# Mannkind Corpor     1.039369e+07       1.216380e+06
# Novo Nordisk        2.505626e+09       7.406664e+07
# Novo Nordisk-Wa     5.164905e+06       1.450119e+06
# Sanofi-Aventis      2.247046e+07       9.332701e+05

# %%
#Avg cost per dosage by manuf Tot_Spndng_2021/Tot_Dsg_Unts_2021

medi_2021_result['Avg_Cost_Per_Dsg_2021'] = medi_2021_result['Tot_Spndng_2021']/medi_2021_result['Tot_Dsg_Unts_2021']
medi_2021_result
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2021  Tot_Dsg_Unts_2021  Avg_Cost_Per_Dsg_2021
# Mftr_Name
# Eli Lilly & Co.     2.357312e+09       7.481477e+07              31.508652
# Mannkind Corpor     1.039369e+07       1.216380e+06               8.544775
# Novo Nordisk        2.505626e+09       7.406664e+07              33.829351
# Novo Nordisk-Wa     5.164905e+06       1.450119e+06               3.561712
# Sanofi-Aventis      2.247046e+07       9.332701e+05              24.077122

# %%
# Configure plot, ,6figsize, title, and axis labels
fig1 = medi_2021_result['Avg_Cost_Per_Dsg_2021'].plot(kind="bar", facecolor="purple", figsize=(8,6),
                             title = "Average Cost Per Dosage 2021",
                             xlabel = "Manufacturer",
                             ylabel = "Avg Cost")

# Configure x-tick rotation
xticklabels = medi_2021_result.index
plt.ticklabel_format(style = 'plain', axis='y')
fig1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)
# Show plot
plt.show()

# %%
# Define the names to filter in the 'Gnrc_Name' column
medi_names_to_filter = ['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']
# Define relevant columns for the year 2019-2021
medi_relevant_columns_2019_2021 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']
# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]
# Select relevant columns for the year 2019-2021
medi_result_2019_2021 = filtered_df[medi_relevant_columns_2019_2021]
# Display the result DataFrame
print(medi_result_2019_2021)
# Out:
#                    Gnrc_Name        Mftr_Name  Tot_Spndng_2019  \
# 243           Insulin Lispro   Sanofi-Aventis     2.076727e+06
# 245           Insulin Lispro   Sanofi-Aventis     5.632924e+06
# 271   Insulin Regular, Human  Mannkind Corpor     7.000875e+06
# 772        Insulin Glulisine   Sanofi-Aventis     5.352751e+06
# 774        Insulin Glulisine   Sanofi-Aventis     1.401256e+07
# 5771          Insulin Lispro  Eli Lilly & Co.     5.492364e+08
# 5773          Insulin Lispro  Eli Lilly & Co.     4.230471e+06
# 5775          Insulin Lispro  Eli Lilly & Co.     1.218056e+09
# 5777          Insulin Lispro  Eli Lilly & Co.     1.402135e+08
# 5815  Insulin Regular, Human  Eli Lilly & Co.     6.623255e+07
# 5817  Insulin Regular, Human  Eli Lilly & Co.     1.077373e+08
# 5819  Insulin Regular, Human  Eli Lilly & Co.     2.067820e+08
# 6211          Insulin Aspart     Novo Nordisk              NaN
# 6213          Insulin Aspart     Novo Nordisk              NaN
# 6215          Insulin Aspart     Novo Nordisk              NaN
# 6221          Insulin Lispro  Eli Lilly & Co.     8.870538e+06
# 6223          Insulin Lispro  Eli Lilly & Co.              NaN
# 6225          Insulin Lispro  Eli Lilly & Co.     2.192407e+07
# 8939  Insulin Regular, Human  Novo Nordisk-Wa     4.525436e+06
# 8940  Insulin Regular, Human     Novo Nordisk     5.640745e+07
# 8942  Insulin Regular, Human  Novo Nordisk-Wa              NaN
# 8943  Insulin Regular, Human     Novo Nordisk              NaN
# 8945          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8946          Insulin Aspart     Novo Nordisk     6.585012e+08
# 8948          Insulin Aspart  Novo Nordisk-Wa              NaN
# 8949          Insulin Aspart     Novo Nordisk     1.843976e+09
# 8957          Insulin Aspart     Novo Nordisk     6.959634e+06
#
#       Tot_Spndng_2020  Tot_Spndng_2021
# 243      2.461450e+06     2.224715e+06
# 245      5.785748e+06     6.137620e+06
# 271      8.007830e+06     1.039369e+07
# 772      4.528780e+06     3.769932e+06
# 774      1.226855e+07     1.033819e+07
# 5771     4.492513e+08     4.350572e+08
# 5773     6.145479e+06     7.637031e+06
# 5775     1.053916e+09     1.076262e+09
# 5777     1.545332e+08     1.785742e+08
# 5815     6.390659e+07     6.092082e+07
# 5817     9.552538e+07     8.820523e+07
# 5819     2.318727e+08     2.493683e+08
# 6211     1.178440e+07     1.982417e+07
# 6213     3.087250e+07     5.999348e+07
# 6215     1.366072e+05     3.643753e+05
# 6221     5.575553e+07     7.068405e+07
# 6223     3.252693e+05     9.763862e+05
# 6225     1.416218e+08     1.896275e+08
# 8939     4.121791e+06     3.178184e+06
# 8940     5.041295e+07     4.504622e+07
# 8942     1.250836e+05     1.998935e+05
# 8943     2.052605e+06     8.286203e+06
# 8945              NaN     8.242499e+05
# 8946     5.869778e+08     5.455735e+08
# 8948              NaN     9.625774e+05
# 8949     1.844084e+09     1.816712e+09
# 8957     8.204522e+06     9.825961e+06

# %%
#Total Spending by Manuf
medi_2019_2021_result = medi_result_2019_2021.groupby('Mftr_Name').sum()
medi_2019_2021_result
#medi_2019_2021_result.columns
# Out:
#                                                          Gnrc_Name  \
# Mftr_Name
# Eli Lilly & Co.  Insulin LisproInsulin LisproInsulin LisproInsu...
# Mannkind Corpor                             Insulin Regular, Human
# Novo Nordisk     Insulin AspartInsulin AspartInsulin AspartInsu...
# Novo Nordisk-Wa  Insulin Regular, HumanInsulin Regular, HumanIn...
# Sanofi-Aventis   Insulin LisproInsulin LisproInsulin GlulisineI...
#
#                  Tot_Spndng_2019  Tot_Spndng_2020  Tot_Spndng_2021
# Mftr_Name
# Eli Lilly & Co.     2.323283e+09     2.252853e+09     2.357312e+09
# Mannkind Corpor     7.000875e+06     8.007830e+06     1.039369e+07
# Novo Nordisk        2.565845e+09     2.534526e+09     2.505626e+09
# Novo Nordisk-Wa     4.525436e+06     4.246875e+06     5.164905e+06
# Sanofi-Aventis      2.707496e+07     2.504453e+07     2.247046e+07

# %%
# Configure plot, ,6figsize, title, and axis labels
fig1 = medi_2019_2021_result.plot(kind="bar", color=["purple", "c", "deeppink"], figsize=(8,6),
                             title = "Total Spending",
                             xlabel = "Manufacturer",
                             ylabel = "Price")

# Configure x-tick rotation
xticklabels = medi_2019_2021_result.index
plt.ticklabel_format(style = 'plain', axis='y')
fig1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)

# Show plot
plt.show()

# %%
# Define the names to filter in the 'Gnrc_Name' column
medi_names_to_filter = ['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']
# Define relevant columns for the year 2019-2021
medi_relevant_columns_2019_2021 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Dsg_Unts_2019', 'Tot_Dsg_Unts_2020', 'Tot_Dsg_Unts_2021']
# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]
# Select relevant columns for the year 2019-2021
medi_result_2019_2021 = filtered_df[medi_relevant_columns_2019_2021]
# Display the result DataFrame
print(medi_result_2019_2021)
# Out:
#                    Gnrc_Name        Mftr_Name  Tot_Dsg_Unts_2019  \
# 243           Insulin Lispro   Sanofi-Aventis       1.200337e+05
# 245           Insulin Lispro   Sanofi-Aventis       1.248402e+06
# 271   Insulin Regular, Human  Mannkind Corpor       9.778800e+05
# 772        Insulin Glulisine   Sanofi-Aventis       1.926600e+05
# 774        Insulin Glulisine   Sanofi-Aventis       3.895440e+05
# 5771          Insulin Lispro  Eli Lilly & Co.       2.068148e+07
# 5773          Insulin Lispro  Eli Lilly & Co.       1.216120e+05
# 5775          Insulin Lispro  Eli Lilly & Co.       3.493181e+07
# 5777          Insulin Lispro  Eli Lilly & Co.       1.976476e+06
# 5815  Insulin Regular, Human  Eli Lilly & Co.       6.641352e+06
# 5817  Insulin Regular, Human  Eli Lilly & Co.       1.456718e+06
# 5819  Insulin Regular, Human  Eli Lilly & Co.       2.203220e+06
# 6211          Insulin Aspart     Novo Nordisk                NaN
# 6213          Insulin Aspart     Novo Nordisk                NaN
# 6215          Insulin Aspart     Novo Nordisk                NaN
# 6221          Insulin Lispro  Eli Lilly & Co.       6.228340e+05
# 6223          Insulin Lispro  Eli Lilly & Co.                NaN
# 6225          Insulin Lispro  Eli Lilly & Co.       1.212082e+06
# 8939  Insulin Regular, Human  Novo Nordisk-Wa       1.605562e+06
# 8940  Insulin Regular, Human     Novo Nordisk       4.008605e+06
# 8942  Insulin Regular, Human  Novo Nordisk-Wa                NaN
# 8943  Insulin Regular, Human     Novo Nordisk                NaN
# 8945          Insulin Aspart  Novo Nordisk-Wa                NaN
# 8946          Insulin Aspart     Novo Nordisk       2.242928e+07
# 8948          Insulin Aspart  Novo Nordisk-Wa                NaN
# 8949          Insulin Aspart     Novo Nordisk       4.916059e+07
# 8957          Insulin Aspart     Novo Nordisk       1.955080e+05
#
#       Tot_Dsg_Unts_2020  Tot_Dsg_Unts_2021
# 243        1.813510e+05       1.617081e+05
# 245        3.392590e+05       3.527900e+05
# 271        1.036929e+06       1.216380e+06
# 772        1.630320e+05       1.340300e+05
# 774        3.406650e+05       2.847420e+05
# 5771       1.724181e+07       1.625795e+07
# 5773       1.787170e+05       2.179480e+05
# 5775       3.057358e+07       3.056684e+07
# 5777       2.184844e+06       2.471033e+06
# 5815       6.494117e+06       6.291980e+06
# 5817       1.289875e+06       1.166660e+06
# 5819       2.466670e+06       2.604695e+06
# 6211       8.014670e+05       1.350051e+06
# 6213       1.665054e+06       3.195601e+06
# 6215       7.929000e+03       2.046100e+04
# 6221       3.938873e+06       4.911638e+06
# 6223       1.798200e+04       5.311500e+04
# 6225       7.819461e+06       1.027291e+07
# 8939       1.452663e+06       1.102257e+06
# 8940       3.551676e+06       3.161736e+06
# 8942       4.338600e+04       6.785100e+04
# 8943       1.149460e+05       4.603196e+05
# 8945                NaN       1.123150e+05
# 8946       1.994095e+07       1.832066e+07
# 8948                NaN       1.676960e+05
# 8949       4.857480e+07       4.728998e+07
# 8957       2.274700e+05       2.678290e+05

# %%
# Configure plot, ,6figsize, title, and axis labels
fig1 = medi_2019_2021_result.plot(kind="bar", color=["purple", "c", "deeppink"], figsize=(8,6),
                             title = "Total Dosage",
                             xlabel = "Manufacturer",
                             ylabel = "Dosage")

# Configure x-tick rotation
xticklabels = medi_2019_2021_result.index
plt.ticklabel_format(style = 'plain', axis='y')
fig1.set_xticklabels(xticklabels, rotation=45, rotation_mode="anchor", ha="right", wrap=True)

# Show plot
plt.show()

# %%
#import pandas as pd
#import matplotlib.pyplot as plt 
import matplotlib.image as mpimg
import requests
from PIL import Image
from io import BytesIO

# %%
medicare_insulin = pd.read_csv('Resources/Medicare_Part_D_Spending_by_Drug_2021.csv')

# %%
# Define the names to filter in the 'Gnrc_Name' column
medi_names_to_filter = ['Insulin Glulisine','Insulin Lispro', 'Insulin Aspart','Insulin Regular, Human']

# Define relevant columns for the year 2019
medi_relevant_columns_2019 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Dsg_Unts_2019', 'Tot_Clms_2019', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2019', 'Avg_Spnd_Per_Clm_2019']

# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]

# Select relevant columns for the year 2019
medi_result_df_2019 = filtered_df[medi_relevant_columns_2019]

# Display the result DataFrame
#print(medi_result_df_2019)

# %%
# Define relevant columns for the year 2020
medi_relevant_columns_2020 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Dsg_Unts_2020', 'Tot_Clms_2020', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2020', 'Avg_Spnd_Per_Clm_2020']

# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]

# Select relevant columns for the year 2020
medi_result_df_2020 = filtered_df[medi_relevant_columns_2020]

# Display the result DataFrame
#print(medi_result_df_2020)

# %%
# Define relevant columns for the year 2021
medi_relevant_columns_2021 = ['Gnrc_Name', 'Mftr_Name', 'Tot_Dsg_Unts_2021', 'Tot_Clms_2021', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2021', 'Avg_Spnd_Per_Clm_2021']

# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]

# Select relevant columns for the year 2021
medi_result_df_2021 = filtered_df[medi_relevant_columns_2021]

# Display the result DataFrame
#print(medi_result_df_2021)

# %%
# Select relevant columns for the year 2019 and drop unwanted columns
medi_result_df_2019 = filtered_df[medi_relevant_columns_2019].drop(['Tot_Dsg_Unts_2019', 'Tot_Clms_2019', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2019'], axis=1)

# Add a dollar sign to 'Avg_Spnd_Per_Clm_2019' column
medi_result_df_2019['Avg_Spnd_Per_Clm_2019'] = '$' + medi_result_df_2019['Avg_Spnd_Per_Clm_2019'].astype(str)

# Drop rows with 'nan' in 'Avg_Spnd_Per_Clm_2019' and keep only actual numeric values
medi_result_df_2019 = medi_result_df_2019[medi_result_df_2019['Avg_Spnd_Per_Clm_2019'] != '$nan']

# Drop null values
medi_result_df_2019.dropna(inplace=True)

# Sort by 'Avg_Spnd_Per_Clm_2019' and get the top 10 claims
medi_top_10_claims_df_2019 = medi_result_df_2019.sort_values(by='Avg_Spnd_Per_Clm_2019', ascending=False).head(10)

# Display the top 10 results with only relevant columns
#print(medi_top_10_claims_df_2019[['Gnrc_Name', 'Mftr_Name', 'Avg_Spnd_Per_Clm_2019']])

# %%
# Select relevant columns for the year 2020 and drop unwanted columns
medi_result_df_2020 = filtered_df[medi_relevant_columns_2020].drop(['Tot_Dsg_Unts_2020', 'Tot_Clms_2020', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2020'], axis=1)

# Add a dollar sign to 'Avg_Spnd_Per_Clm_2020' column
medi_result_df_2020['Avg_Spnd_Per_Clm_2020'] = '$' + medi_result_df_2020['Avg_Spnd_Per_Clm_2020'].astype(str)

# Drop rows with 'nan' in 'Avg_Spnd_Per_Clm_2020' and keep only actual numeric values
medi_result_df_2020 = medi_result_df_2020[medi_result_df_2020['Avg_Spnd_Per_Clm_2020'] != '$nan']

# Drop null values
medi_result_df_2020.dropna(inplace=True)

# Sort by 'Avg_Spnd_Per_Clm_2020' and get the top 10 claims
medi_top_10_claims_df_2020 = medi_result_df_2020.sort_values(by='Avg_Spnd_Per_Clm_2020', ascending=False).head(10)

# Display the top 10 results with only relevant columns
#print(medi_top_10_claims_df_2020[['Gnrc_Name', 'Mftr_Name', 'Avg_Spnd_Per_Clm_2020']])

# %%
# Select relevant columns for the year 2021 and drop unwanted columns
medi_result_df_2021 = filtered_df[medi_relevant_columns_2021].drop(['Tot_Dsg_Unts_2021', 'Tot_Clms_2021', 'Avg_Spnd_Per_Dsg_Unt_Wghtd_2021'], axis=1)

# Add a dollar sign to 'Avg_Spnd_Per_Clm_2021' column
medi_result_df_2021['Avg_Spnd_Per_Clm_2021'] = '$' + medi_result_df_2021['Avg_Spnd_Per_Clm_2021'].astype(str)

# Drop rows with 'nan' in 'Avg_Spnd_Per_Clm_2021' and keep only actual numeric values
medi_result_df_2021 = medi_result_df_2021[medi_result_df_2021['Avg_Spnd_Per_Clm_2021'] != '$nan']

# Drop null values
medi_result_df_2021.dropna(inplace=True)

# Sort by 'Avg_Spnd_Per_Clm_2021' and get the top 10 claims
medi_top_10_claims_df_2021 = medi_result_df_2021.sort_values(by='Avg_Spnd_Per_Clm_2021', ascending=False).head(10)

# Display the top 10 results with only relevant columns
#print(medi_top_10_claims_df_2021[['Gnrc_Name', 'Mftr_Name', 'Avg_Spnd_Per_Clm_2021']])

# %%
# Define relevant columns for the years 2019, 2020, and 2021
medi_relevant_columns = ['Gnrc_Name', 'Mftr_Name', 'Avg_Spnd_Per_Clm_2019', 'Avg_Spnd_Per_Clm_2020', 'Avg_Spnd_Per_Clm_2021']

# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' conditions
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]

# Created a copy of the DataFrame to avoid Setting With Copy Warning
medi_result_df = filtered_df[medi_relevant_columns].copy()

# Add dollar signs to 'Avg_Spnd_Per_Clm' columns
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Avg_Spnd_Per_Clm_{year}'] = '$' + medi_result_df[f'Avg_Spnd_Per_Clm_{year}'].astype(str)

# Combine 'Avg_Spnd_Per_Clm' columns for the years 2019, 2020, and 2021
medi_result_df['Combined_Avg_Spnd_Per_Clm'] = medi_result_df[['Avg_Spnd_Per_Clm_2019', 'Avg_Spnd_Per_Clm_2020', 'Avg_Spnd_Per_Clm_2021']].agg(','.join, axis=1)

# Drop rows where any 'Avg_Spnd_Per_Clm' column is null
medi_result_df = medi_result_df.dropna(subset=[f'Avg_Spnd_Per_Clm_{year}' for year in ['2019', '2020', '2021']])

# Add a column indicating the years
medi_result_df['Years'] = medi_result_df.apply(lambda row: ', '.join([year for year in ['2019', '2020', '2021'] if row[f'Avg_Spnd_Per_Clm_{year}'] != '$nan']), axis=1)

# Sort by 'Combined_Avg_Spnd_Per_Clm' and get the top 5 claims
top_5_claims_df = medi_result_df.sort_values(by='Combined_Avg_Spnd_Per_Clm', ascending=False).head(5)

# Display the top 5 result DataFrame with only relevant columns
#print(top_5_claims_df[['Gnrc_Name', 'Mftr_Name', 'Combined_Avg_Spnd_Per_Clm', 'Years']])

# %%
# Define relevant columns for the years 2019, 2020, and 2021
medi_relevant_columns = ['Gnrc_Name', 'Mftr_Name', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']

# Filter rows based on 'Gnrc_Name' and 'Mftr_Name' 
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]


# Created a copy of the DataFrame to avoid Setting With Copy Warning
medi_result_df = filtered_df[medi_relevant_columns].copy()

# Adding dollar signs to 'Tot_Spndng' columns
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Tot_Spndng_{year}'] = '$' + medi_result_df[f'Tot_Spndng_{year}'].astype(str)

# Convert 'Tot_Spndng' columns to numeric
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Tot_Spndng_{year}'] = pd.to_numeric(medi_result_df[f'Tot_Spndng_{year}'].str.replace('$', ''), errors='coerce')

# Drop rows where any 'Tot_Spndng' column is null
medi_result_df = medi_result_df.dropna(subset=[f'Tot_Spndng_{year}' for year in ['2019', '2020', '2021']])

# Display the top 10 for each year with commas and a dollar sign
for year in ['2019', '2020', '2021']:
    top_10_df = medi_result_df.nlargest(10, f'Tot_Spndng_{year}')[['Gnrc_Name', f'Tot_Spndng_{year}']]
    top_10_df[f'Tot_Spndng_{year}'] = top_10_df[f'Tot_Spndng_{year}'].apply(lambda x: '${:,.0f}'.format(x))
    grand_total = top_10_df[f'Tot_Spndng_{year}'].str.replace('[$,]', '', regex=True).astype(float).sum()
    print(f'Top 10 for {year}:')
    print(top_10_df)
    print('Grand Total for {}: ${:,.0f}'.format(year, grand_total))
    print('\n')
# Out:
# Top 10 for 2019:
#                    Gnrc_Name Tot_Spndng_2019
# 8949          Insulin Aspart  $1,843,976,249
# 5775          Insulin Lispro  $1,218,056,279
# 8946          Insulin Aspart    $658,501,236
# 5771          Insulin Lispro    $549,236,374
# 5819  Insulin Regular, Human    $206,782,027
# 5777          Insulin Lispro    $140,213,500
# 5817  Insulin Regular, Human    $107,737,316
# 5815  Insulin Regular, Human     $66,232,554
# 8940  Insulin Regular, Human     $56,407,454
# 6225          Insulin Lispro     $21,924,068
# Grand Total for 2019: $4,869,067,057
#
#
# Top 10 for 2020:
#                    Gnrc_Name Tot_Spndng_2020
# 8949          Insulin Aspart  $1,844,084,368
# 5775          Insulin Lispro  $1,053,915,810
# 8946          Insulin Aspart    $586,977,753
# 5771          Insulin Lispro    $449,251,292
# 5819  Insulin Regular, Human    $231,872,669
# 5777          Insulin Lispro    $154,533,157
# 6225          Insulin Lispro    $141,621,808
# 5817  Insulin Regular, Human     $95,525,385
# 5815  Insulin Regular, Human     $63,906,594
# 6221          Insulin Lispro     $55,755,528
# Grand Total for 2020: $4,677,444,364
#
#
# Top 10 for 2021:
#                    Gnrc_Name Tot_Spndng_2021
# 8949          Insulin Aspart  $1,816,712,462
# 5775          Insulin Lispro  $1,076,261,741
# 8946          Insulin Aspart    $545,573,494
# 5771          Insulin Lispro    $435,057,237
# 5819  Insulin Regular, Human    $249,368,259
# 6225          Insulin Lispro    $189,627,463
# 5777          Insulin Lispro    $178,574,229
# 5817  Insulin Regular, Human     $88,205,232
# 6221          Insulin Lispro     $70,684,052
# 5815  Insulin Regular, Human     $60,920,819
# Grand Total for 2021: $4,710,984,988

# %%
# Created a copy of the DataFrame to avoid Setting With Copy Warning
medi_result_df = filtered_df[medi_relevant_columns].copy()

# Add dollar signs to 'Tot_Spndng' columns
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Tot_Spndng_{year}'] = '$' + medi_result_df[f'Tot_Spndng_{year}'].astype(str)

# Convert 'Tot_Spndng' columns to numeric
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Tot_Spndng_{year}'] = pd.to_numeric(medi_result_df[f'Tot_Spndng_{year}'].str.replace('$', ''), errors='coerce')

# Drop rows where any 'Tot_Spndng' column is null
medi_result_df = medi_result_df.dropna(subset=[f'Tot_Spndng_{year}' for year in ['2019', '2020', '2021']])

# Group by 'Gnrc_Name' and sum the total spending for each year
grouped_df = medi_result_df.groupby('Gnrc_Name')[[f'Tot_Spndng_{year}' for year in ['2019', '2020', '2021']]].sum()

# Define different colors for each bar
colors = ['blue', 'purple', 'gold']

# Plot a bar graph for each year with distinct colors
for year, color in zip(['2019', '2020', '2021'], colors):
    plt.figure(figsize=(10, 6))
    grouped_df[f'Tot_Spndng_{year}'].sort_values(ascending=False).head(10).plot(kind='bar', color=color)
    plt.title(f'Top 10 Total Spending for {year}')
    plt.xlabel('Generic Name')
    plt.ylabel('Total Spending ($)')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %%
# Define relevant columns for the years 2019, 2020, and 2021
medi_relevant_columns = ['Gnrc_Name', 'Mftr_Name', 'Tot_Benes_2019', 'Tot_Benes_2020', 'Tot_Benes_2021']

# Filter rows based on 'Gnrc_Name' and 'Mftr_Name'
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]

# Created a copy of the DataFrame to avoid Setting With Copy Warning
medi_result_df = filtered_df[medi_relevant_columns].copy()

# Convert 'Tot_Benes' columns to numeric without removing dollar signs
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Tot_Benes_{year}'] = pd.to_numeric(medi_result_df[f'Tot_Benes_{year}'], errors='coerce')

# Drop rows where any 'Tot_Benes' column is null
medi_result_df = medi_result_df.dropna(subset=[f'Tot_Benes_{year}' for year in ['2019', '2020', '2021']])

# Display the top 10 for each year without decimal places and with commas
for year in ['2019', '2020', '2021']:
    top_10_df = medi_result_df.nlargest(10, f'Tot_Benes_{year}')[['Gnrc_Name', f'Tot_Benes_{year}']]
    top_10_df[f'Tot_Benes_{year}'] = top_10_df[f'Tot_Benes_{year}'].apply(lambda x: '{:,.0f}'.format(x))
    grand_total = top_10_df[f'Tot_Benes_{year}'].str.replace(',', '').astype(float).sum()
    print(f'Top 10 for {year}:')
    print(top_10_df)
    print('Grand Total for {}: {:,.0f}'.format(year, grand_total))
    print('\n')
# Out:
# Top 10 for 2019:
#                    Gnrc_Name Tot_Benes_2019
# 8949          Insulin Aspart        602,071
# 5775          Insulin Lispro        438,874
# 5771          Insulin Lispro        246,647
# 8946          Insulin Aspart        236,250
# 5815  Insulin Regular, Human         87,122
# 8940  Insulin Regular, Human         59,452
# 6225          Insulin Lispro         38,883
# 5777          Insulin Lispro         29,239
# 5819  Insulin Regular, Human         21,697
# 6221          Insulin Lispro         17,903
# Grand Total for 2019: 1,778,138
#
#
# Top 10 for 2020:
#                    Gnrc_Name Tot_Benes_2020
# 8949          Insulin Aspart        585,300
# 5775          Insulin Lispro        384,871
# 8946          Insulin Aspart        199,643
# 5771          Insulin Lispro        192,852
# 6225          Insulin Lispro        153,626
# 5815  Insulin Regular, Human         79,167
# 6221          Insulin Lispro         66,303
# 8940  Insulin Regular, Human         50,740
# 5777          Insulin Lispro         30,870
# 5819  Insulin Regular, Human         23,199
# Grand Total for 2020: 1,766,571
#
#
# Top 10 for 2021:
#                    Gnrc_Name Tot_Benes_2021
# 8949          Insulin Aspart        564,394
# 5775          Insulin Lispro        374,293
# 6225          Insulin Lispro        182,024
# 8946          Insulin Aspart        173,100
# 5771          Insulin Lispro        167,509
# 5815  Insulin Regular, Human         73,720
# 6221          Insulin Lispro         71,340
# 8940  Insulin Regular, Human         42,474
# 5777          Insulin Lispro         34,271
# 5819  Insulin Regular, Human         24,753
# Grand Total for 2021: 1,707,878

# %%
# Create a copy of the DataFrame to avoid Setting With Copy Warning
medi_result_df = filtered_df[medi_relevant_columns].copy()

# Add dollar signs to 'Tot_Benes' columns
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Tot_Benes_{year}'] = '$' + medi_result_df[f'Tot_Benes_{year}'].astype(str)

# Convert 'Tot_Benes' columns to numeric
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Tot_Benes_{year}'] = pd.to_numeric(medi_result_df[f'Tot_Benes_{year}'].str.replace('$', ''), errors='coerce')

# Drop rows where any 'Tot_Benes' column is null
medi_result_df = medi_result_df.dropna(subset=[f'Tot_Benes_{year}' for year in ['2019', '2020', '2021']])

# Group by 'Gnrc_Name' and sum the total beneficiaries for each year
grouped_df = medi_result_df.groupby('Gnrc_Name')[[f'Tot_Benes_{year}' for year in ['2019', '2020', '2021']]].sum()

# Print the columns to check their names
print(grouped_df.columns)


# Define different colors for each bar
colors = ['red', 'green', 'brown']

# Plot a bar graph for each year
for year, color in zip(['2019', '2020', '2021'], colors):
    plt.figure(figsize=(8, 6))
    grouped_df.sort_values(by=f'Tot_Benes_{year}', ascending=False).head(10)[f'Tot_Benes_{year}'].plot(kind='bar', color=color)
    plt.title(f'Top 10 Total Beneficiaries for {year}')
    plt.xlabel('Generic Name')
    plt.ylabel('Total Beneficiaries')
    plt.xticks(rotation=45, ha='right')
    plt.show()
# Out:
# Index(['Tot_Benes_2019', 'Tot_Benes_2020', 'Tot_Benes_2021'], dtype='object')

# %%
# Define relevant columns for the years 2019, 2020, and 2021
medi_relevant_columns = ['Gnrc_Name', 'Mftr_Name', 'Tot_Benes_2019', 'Tot_Benes_2020', 'Tot_Benes_2021', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']

# Filter rows based on 'Gnrc_Name' and 'Mftr_Name'
filtered_df = medicare_insulin[medicare_insulin['Gnrc_Name'].isin(medi_names_to_filter) & ~medicare_insulin['Mftr_Name'].str.contains('Overall')]

# Create a copy of the DataFrame to avoid Setting With Copy Warning
medi_result_df = filtered_df[medi_relevant_columns].copy()

# Convert 'Tot_Benes' and 'Tot_Spndng' columns to numeric without removing dollar signs
for col in ['Tot_Benes_2019', 'Tot_Benes_2020', 'Tot_Benes_2021', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021']:
    medi_result_df[col] = pd.to_numeric(medi_result_df[col].astype(str).str.replace('$', '').str.replace(',', ''), errors='coerce')

# Drop rows where any relevant column is null
medi_result_df = medi_result_df.dropna(subset=['Tot_Benes_2019', 'Tot_Benes_2020', 'Tot_Benes_2021', 'Tot_Spndng_2019', 'Tot_Spndng_2020', 'Tot_Spndng_2021'])

# Calculate the ratio of 'Tot_Spndng' to 'Tot_Benes' for each year
for year in ['2019', '2020', '2021']:
    medi_result_df[f'Ratio_{year}'] = medi_result_df[f'Tot_Spndng_{year}'] / medi_result_df[f'Tot_Benes_{year}']

# Display the top 10 for each year with commas and a dollar sign
for year in ['2019', '2020', '2021']:
    top_10_df = medi_result_df.nlargest(10, f'Ratio_{year}')[['Gnrc_Name', f'Ratio_{year}']]
    top_10_df[f'Ratio_{year}'] = top_10_df[f'Ratio_{year}'].apply(lambda x: '${:,.2f}'.format(x))
    grand_total = medi_result_df[f'Tot_Spndng_{year}'].sum() / medi_result_df[f'Tot_Benes_{year}'].sum()
    print(f'Top 10 for {year}:')
    print(top_10_df)
    print(f'Grand Total for {year}: ${grand_total:.2f}\n')
# Out:
# Top 10 for 2019:
#                    Gnrc_Name  Ratio_2019
# 5817  Insulin Regular, Human  $10,799.65
# 5819  Insulin Regular, Human   $9,530.44
# 271   Insulin Regular, Human   $5,014.95
# 5777          Insulin Lispro   $4,795.43
# 772        Insulin Glulisine   $3,429.05
# 774        Insulin Glulisine   $3,109.07
# 8949          Insulin Aspart   $3,062.72
# 8946          Insulin Aspart   $2,787.31
# 5775          Insulin Lispro   $2,775.41
# 5771          Insulin Lispro   $2,226.81
# Grand Total for 2019: $2687.76
#
# Top 10 for 2020:
#                    Gnrc_Name  Ratio_2020
# 5817  Insulin Regular, Human  $11,114.06
# 5819  Insulin Regular, Human   $9,994.94
# 271   Insulin Regular, Human   $6,305.38
# 5777          Insulin Lispro   $5,005.93
# 772        Insulin Glulisine   $3,951.82
# 774        Insulin Glulisine   $3,364.94
# 8949          Insulin Aspart   $3,150.67
# 8946          Insulin Aspart   $2,940.14
# 5775          Insulin Lispro   $2,738.36
# 5771          Insulin Lispro   $2,329.51
# Grand Total for 2020: $2621.79
#
# Top 10 for 2021:
#                    Gnrc_Name  Ratio_2021
# 5817  Insulin Regular, Human  $11,396.02
# 5819  Insulin Regular, Human  $10,074.26
# 271   Insulin Regular, Human   $7,429.37
# 5777          Insulin Lispro   $5,210.65
# 772        Insulin Glulisine   $4,049.34
# 774        Insulin Glulisine   $3,506.85
# 8949          Insulin Aspart   $3,218.87
# 8946          Insulin Aspart   $3,151.78
# 5775          Insulin Lispro   $2,875.45
# 5771          Insulin Lispro   $2,597.22
# Grand Total for 2021: $2729.03

# %%
# While Insulin Spend in 2019 was the highest, it also had the highest number of Beneficiaries. 
#Yet the ratio to spend was lower than that of 2021 which also had far less beneficiaries. 
# We can possibly attribute this spend to cost increase due to the Pandemic.

# %%
# Read file into DataFrame
cpi_df = pd.read_csv('Resources/FPCPITOTLZGUSA.csv')
#medi_df.head(20)
cpi_df
# Out:
#           DATE  FPCPITOTLZGUSA
# 0   1960-01-01        1.457976
# 1   1961-01-01        1.070724
# 2   1962-01-01        1.198773
# 3   1963-01-01        1.239669
# 4   1964-01-01        1.278912
# ..         ...             ...
# 58  2018-01-01        2.442583
# 59  2019-01-01        1.812210
# 60  2020-01-01        1.233584
# 61  2021-01-01        4.697859
# 62  2022-01-01        8.002800
#
# [63 rows x 2 columns]

# %%
#Get rid of data not need it
cpi_df_19_21 = cpi_df.tail(4)
cpi_df_19_21 = cpi_df_19_21.head(3)
cpi_df_19_21
# Out:
#           DATE  FPCPITOTLZGUSA
# 59  2019-01-01        1.812210
# 60  2020-01-01        1.233584
# 61  2021-01-01        4.697859

# %%
cpi_df_19_21['DATE'] = cpi_df_19_21['DATE'].str.split('-').str[0]
cpi_df_19_21

# %%
cpi_df_19_21.rename(columns={'DATE' : 'Year', 'FPCPITOTLZGUSA' : 'C.P.I.'}, inplace=True)
cpi_df_19_21

# %%
cpi_df_19_21 = cpi_df_19_21.set_index('Year')
cpi_df_19_21

# %%
#Graph CPI / Year

#import matplotlib
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

cpi_df_19_21.plot(kind='bar')

plt.title('Consumer Price Index - Years 2019-2021')
#plt.xlabel('Year')
#plt.ylabel('C.P.I.')
plt.ticklabel_format(style='plain', axis='y')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig('Resources/CPI_plot.png')
plt.show()

# %%
# Path to the JPEG file on Resources
file_path = "Resources/Phoenix.jpg"   

# Open the image
img = Image.open(file_path)

# Create a centered figure
fig, ax = plt.subplots(figsize=(12, 12))
fig.subplots_adjust(left=0.2, right=0.8, top=0.8, bottom=0.2)  

# Display the image
ax.imshow(img)
ax.axis('off')  
plt.title("Phoenix Rising", fontsize=16)
plt.show()
